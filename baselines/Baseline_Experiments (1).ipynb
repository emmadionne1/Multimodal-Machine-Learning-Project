# %% [markdown]
# ##Baselines:
#
# Unimodal:
# - Text: Questions --> Qwen LLM --> Answer
# - Chart to Table: Image --> Table --> Qwen LLM --> Answer
#
# Simple:
# - Image --> CLIP --> projection --> + question --> GPT-2/Qwen3B LLM --> Answer
#
# SOTA:
# - UniChart
# - AskChart

# %%
import torch
from tqdm import tqdm
import re
import pandas as pd

from huggingface_hub import login
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
# Load data
import polars as pl
import pandas as pd

from huggingface_hub import login
login(token="hf token")

from datasets import load_dataset

ds = load_dataset("HuggingFaceM4/ChartQA")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/852 [00:00<?, ?B/s]
# data/train-00000-of-00003-49492f364babfa(…):   0%|          | 0.00/219M [00:00<?, ?B/s]
# data/train-00001-of-00003-7302bae5e425bb(…):   0%|          | 0.00/311M [00:00<?, ?B/s]
# data/train-00002-of-00003-194c9400785577(…):   0%|          | 0.00/315M [00:00<?, ?B/s]
# data/val-00000-of-00001-0f11003c77497969(…):   0%|          | 0.00/50.2M [00:00<?, ?B/s]
# data/test-00000-of-00001-e2cd0b7a0f9eb20(…):   0%|          | 0.00/68.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/28299 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/1920 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2500 [00:00<?, ? examples/s]

# %% [markdown]
# ## Unimodal Baseline: Text

# %%
model_name = "Qwen/Qwen3-4B-Instruct-2507"

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.padding_side = "left"
tokenizer.pad_token = tokenizer.eos_token

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)

model.eval()
# Out:
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# Qwen3ForCausalLM(
#   (model): Qwen3Model(
#     (embed_tokens): Embedding(151936, 2560)
#     (layers): ModuleList(
#       (0-35): 36 x Qwen3DecoderLayer(
#         (self_attn): Qwen3Attention(
#           (q_proj): Linear(in_features=2560, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (v_proj): Linear(in_features=2560, out_features=1024, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=2560, bias=False)
#           (q_norm): Qwen3RMSNorm((128,), eps=1e-06)
#           (k_norm): Qwen3RMSNorm((128,), eps=1e-06)
#         )
#         (mlp): Qwen3MLP(
#           (gate_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (up_proj): Linear(in_features=2560, out_features=9728, bias=False)
#           (down_proj): Linear(in_features=9728, out_features=2560, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#         (post_attention_layernorm): Qwen3RMSNorm((2560,), eps=1e-06)
#       )
#     )
#     (norm): Qwen3RMSNorm((2560,), eps=1e-06)
#     (rotary_emb): Qwen3RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=2560, out_features=151936, bias=False)
# )

# %%
def clean_prediction(text):
    """
    Extract first short answer from model output.
    """
    text = text.strip()
    text = text.split("\n")[0]
    text = text.split("Answer:")[-1]
    return text.strip().strip(".")


def normalize_text(text):
    return text.lower().strip()


def extract_number(text):
    """
    Extract first numeric value from string if present.
    """
    match = re.search(r"-?\d+\.?\d*", text.replace(",", ""))
    if match:
        return float(match.group())
    return None


def relaxed_numeric_match(pred, gt, tol=0.05):
    """
    ±5% tolerance numeric accuracy
    """
    pred_num = extract_number(pred)
    gt_num = extract_number(gt)

    if pred_num is None or gt_num is None:
        return False

    return abs(pred_num - gt_num) / (abs(gt_num) + 1e-8) <= tol

# %%
def generate_answer(question):
    prompt = (
        "Answer the following chart question with a single short answer.\n\n"
        f"Question: {question}\n"
        "Answer:"
    )

    messages = [
        {"role": "user", "content": prompt},
    ]

    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        return_dict=True,
        return_tensors="pt",
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=40,
            do_sample=False,      # deterministic baseline
            temperature=0.0
        )

    response = tokenizer.decode(
        outputs[0][inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )

    return clean_prediction(response)

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("Model device:", next(model.parameters()).device)


split = ds["val"]
batch_size = 8   # T4 sweet spot (try 8 or 16)

exact_correct = 0
relaxed_correct = 0
total = 0

results = []

def build_prompt(question):
    return (
        "Answer the following chart question with a single short answer.\n\n"
        f"Question: {question}\n"
        "Answer:"
    )

for i in tqdm(range(0, len(split), batch_size)):

    batch = split[i:i+batch_size]

    questions = batch["query"]
    gt_lists = batch["label"]

    prompts = [build_prompt(q) for q in questions]

    messages_batch = [
        [{"role": "user", "content": p}]
        for p in prompts
    ]

    inputs = tokenizer.apply_chat_template(
        messages_batch,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_tensors="pt",
        return_dict=True,
    ).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=40,
            do_sample=False
        )

    generated_tokens = outputs[:, inputs["input_ids"].shape[-1]:]
    preds = tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)

    for question, pred, gt_list in zip(questions, preds, gt_lists):

        pred = clean_prediction(pred)
        pred_norm = normalize_text(pred)

        exact = False
        relaxed = False

        for gt in gt_list:
            gt_norm = normalize_text(str(gt))

            if pred_norm == gt_norm:
                exact = True
                relaxed = True
                break

            if relaxed_numeric_match(pred, str(gt)):
                relaxed = True

        if exact:
            exact_correct += 1
        if relaxed:
            relaxed_correct += 1

        total += 1

        results.append({
            "question": question,
            "ground_truth": gt_list,
            "prediction": pred,
            "exact_match": exact,
            "relaxed_match": relaxed
        })

# Final metrics
exact_acc = exact_correct / total
relaxed_acc = relaxed_correct / total

print("\n==============================")
print("TEXT-ONLY BASELINE RESULTS")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_acc:.4f}")
print(f"Relaxed Accuracy (±5%): {relaxed_acc:.4f}")


for r in results[:5]:
    print(r["question"])
    print("GT:", r["ground_truth"])
    print("Pred:", r["prediction"])
    print()
df = pd.DataFrame(results)
df.to_csv("chartqa_text_only_results_full.csv", index=False)
# Out:
# CUDA available: True
# Device: NVIDIA RTX PRO 6000 Blackwell Server Edition
# Model device: cuda:0
#   4%|▍         | 10/240 [00:06<02:28,  1.55it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2950867429.py in <cell line: 0>()
#      46
#      47     with torch.no_grad():
# ---> 48         outputs = model.generate(
#      49             **inputs,
#      50             max_new_tokens=40,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2667
#    2668         # 9. Call generation mode
# -> 2669         result = decoding_method(
#    2670             self,
#    2671             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2872                 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2873                 with self._optimize_model_for_decode():
# -> 2874                     outputs = model_forward(**model_inputs, return_dict=True)
#    2875             prefill_consumed = True
#    2876             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     833         if return_dict_passed is not None:
#     834             return_dict = return_dict_passed
# --> 835         output = func(self, *args, **kwargs)
#     836         if not return_dict and not isinstance(output, tuple):
#     837             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     503         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     504         ```"""
# --> 505         outputs: BaseModelOutputWithPast = self.model(
#     506             input_ids=input_ids,
#     507             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1000                         outputs = func(self, *args, **kwargs)
#    1001                 else:
# -> 1002                     outputs = func(self, *args, **kwargs)
#    1003             except TypeError as original_exception:
#    1004                 # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     433
#     434         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 435             hidden_states = decoder_layer(
#     436                 hidden_states,
#     437                 attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     319     ) -> torch.Tensor:
#     320         residual = hidden_states
# --> 321         hidden_states = self.input_layernorm(hidden_states)
#     322         # Self Attention
#     323         hidden_states, _ = self.self_attn(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, hidden_states)
#      59         input_dtype = hidden_states.dtype
#      60         hidden_states = hidden_states.to(torch.float32)
# ---> 61         variance = hidden_states.pow(2).mean(-1, keepdim=True)
#      62         hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#      63         return self.weight * hidden_states.to(input_dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Unimodal Baseline: Chart to Table

# %%
from transformers import DonutProcessor, VisionEncoderDecoderModel
from PIL import Image
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# Use a Donut model finetuned on structured documents (CORD / tables)
donut_model_name = "naver-clova-ix/donut-base-finetuned-cord-v2"

processor = DonutProcessor.from_pretrained(donut_model_name)
ocr_model = VisionEncoderDecoderModel.from_pretrained(donut_model_name).to(device)
# Out:
# preprocessor_config.json:   0%|          | 0.00/362 [00:00<?, ?B/s]
# The image processor of type `DonutImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/806M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/484 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie decoder.model.decoder.embed_tokens.weight to decoder.lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning

# %%
# from transformers import TrOCRProcessor, VisionEncoderDecoderModel

# ocr_model_name = "microsoft/trocr-base-printed"
# processor = TrOCRProcessor.from_pretrained(ocr_model_name)
# ocr_model = VisionEncoderDecoderModel.from_pretrained(ocr_model_name).to("cuda")

# from paddleocr import PaddleOCR
# ocr_model = PaddleOCR(use_angle_cls=True, lang='en')
# Out:
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1777309056.py in <cell line: 0>()
#       5 # ocr_model = VisionEncoderDecoderModel.from_pretrained(ocr_model_name).to("cuda")
#       6
# ----> 7 from paddleocr import PaddleOCR
#       8 ocr_model = PaddleOCR(use_angle_cls=True, lang='en')
#
# /usr/local/lib/python3.12/dist-packages/paddleocr/__init__.py in <module>
#      13 # limitations under the License.
#      14
# ---> 15 from paddlex.inference.utils.benchmark import benchmark
#      16
#      17 from ._models import (
#
# /usr/local/lib/python3.12/dist-packages/paddlex/__init__.py in <module>
#      47
#      48
# ---> 49 from .inference import create_pipeline, create_predictor
#      50 from .model import create_model
#      51 from .modules import build_dataset_checker, build_evaluator, build_trainer
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/__init__.py in <module>
#      14
#      15 from ..utils import logging
# ---> 16 from .models import create_predictor
#      17 from .pipelines import create_pipeline, load_pipeline_config
#      18 from .utils.hpi import HPIConfig
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/models/__init__.py in <module>
#      20 from ...utils import errors
#      21 from ..utils.hpi import HPIConfig
# ---> 22 from ..utils.official_models import official_models
#      23 from .anomaly_detection import UadPredictor
#      24 from .base import BasePredictor
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/utils/official_models.py in <module>
#     646
#     647
# --> 648 official_models = _ModelManager()
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/utils/official_models.py in __init__(self)
#     562
#     563     def __init__(self) -> None:
# --> 564         self._hosters = self._build_hosters()
#     565
#     566     def _build_hosters(self):
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/utils/official_models.py in _build_hosters(self)
#     587                     hosters.insert(0, hoster_cls(self._save_dir))
#     588             else:
# --> 589                 if hoster_cls.is_available():
#     590                     hosters.append(hoster_cls(self._save_dir))
#     591         if len(hosters) == 0:
#
# /usr/local/lib/python3.12/dist-packages/paddlex/inference/utils/official_models.py in is_available(cls)
#     451             return True
#     452         try:
# --> 453             response = requests.head(
#     454                 cls.healthcheck_url, timeout=cls._healthcheck_timeout
#     455             )
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in head(url, **kwargs)
#      98
#      99     kwargs.setdefault("allow_redirects", False)
# --> 100     return request("head", url, **kwargs)
#     101
#     102
#
# /usr/local/lib/python3.12/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.12/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.12/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     665
#     666         try:
# --> 667             resp = conn.urlopen(
#     668                 method=request.method,
#     669                 url=url,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     785
#     786             # Make the request on the HTTPConnection object
# --> 787             response = self._make_request(
#     788                 conn,
#     789                 method,
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532         # Receive the response from the server
#     533         try:
# --> 534             response = conn.getresponse()
#     535         except (BaseSSLError, OSError) as e:
#     536             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.12/dist-packages/urllib3/connection.py in getresponse(self)
#     563
#     564         # Get the response from http.client.HTTPConnection
# --> 565         httplib_response = super().getresponse()
#     566
#     567         try:
#
# /usr/lib/python3.12/http/client.py in getresponse(self)
#    1428         try:
#    1429             try:
# -> 1430                 response.begin()
#    1431             except ConnectionError:
#    1432                 self.close()
#
# /usr/lib/python3.12/http/client.py in begin(self)
#     329         # read until we get a non-100 response
#     330         while True:
# --> 331             version, status, reason = self._read_status()
#     332             if status != CONTINUE:
#     333                 break
#
# /usr/lib/python3.12/http/client.py in _read_status(self)
#     290
#     291     def _read_status(self):
# --> 292         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293         if len(line) > _MAXLINE:
#     294             raise LineTooLong("status line")
#
# /usr/lib/python3.12/socket.py in readinto(self, b)
#     718         while True:
#     719             try:
# --> 720                 return self._sock.recv_into(b)
#     721             except timeout:
#     722                 self._timeout_occurred = True
#
# /usr/lib/python3.12/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1249                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250                   self.__class__)
# -> 1251             return self.read(nbytes, buffer)
#    1252         else:
#    1253             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.12/ssl.py in read(self, len, buffer)
#    1101         try:
#    1102             if buffer is not None:
# -> 1103                 return self._sslobj.read(len, buffer)
#    1104             else:
#    1105                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
qwen_model_name = "Qwen/Qwen3-4B-Instruct-2507"
tokenizer = AutoTokenizer.from_pretrained(qwen_model_name)
tokenizer.padding_side = "left"
tokenizer.pad_token = tokenizer.eos_token
qwen_model = AutoModelForCausalLM.from_pretrained(
    qwen_model_name,
    torch_dtype=torch.float16,
    device_map="auto"
)
# Out:
# model.safetensors:   0%|          | 0.00/806M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]

# %%
from PIL import Image
def ocr_extract_text(image_or_path):
    """Extract text from PIL Image or path using TrOCR"""
    if isinstance(image_or_path, str):
        image = Image.open(image_or_path).convert("RGB")
    else:
        image = image_or_path.convert("RGB")

    pixel_values = processor(images=image, return_tensors="pt").pixel_values.to("cuda")
    with torch.no_grad():
        generated_ids = ocr_model.generate(pixel_values)
    text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return text.strip()

def ocr_to_table_text(raw_text):
    """Convert OCR text to Markdown-like table"""
    lines = raw_text.split("\n")
    lines = [l.strip() for l in lines if l.strip()]
    # replace multiple spaces with pipe separators
    lines = [" | ".join(l.split()) for l in lines]
    table_text = "\n".join(lines)
    return table_text



def generate_answer_from_table(table_text, question):
    """Pass table text + question to Qwen"""
    prompt = f"Given the following table extracted from a chart:\n\n{table_text}, Question: {question}, \n\nAnswer:"
    messages = [{"role": "user", "content": prompt}]
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_dict=True,
        return_tensors="pt",
    ).to(qwen_model.device)
    with torch.no_grad():
        outputs = qwen_model.generate(**inputs, max_new_tokens=60, do_sample=False)
    answer = tokenizer.decode(outputs[0][inputs["input_ids"].shape[-1]:], skip_special_tokens=True)
    return answer.strip()

# %%
import torch
import pandas as pd
from tqdm import tqdm
from PIL import Image

# ------------------------------
# 1. Setup
# ------------------------------
print("CUDA available:", torch.cuda.is_available())
print("Device:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "CPU")
print("Model device:", next(qwen_model.parameters()).device)

# Use first 50 validation examples
split = ds["val"]#.select(range(25))
split_list = [dict(ex) for ex in split]
batch_size = 4  # safe for Qwen3-4B on your GPU

exact_correct = 0
relaxed_correct = 0
total = 0
results = []

# ------------------------------
# 2. Helper functions
# ------------------------------
def build_prompt(table_text, question):
    return (
        f"Given the following table extracted from a chart:\n\n{table_text}\n\n"
        f"Answer the following question:\n{question}\nAnswer:"
    )

# ------------------------------
# 3. Batched loop
# ------------------------------
for i in tqdm(range(0, len(split_list), batch_size)):
    batch = split_list[i:i+batch_size]

    # ------------------------------
    # 3a. OCR each chart → table
    # ------------------------------
    raw_texts = []
    table_texts = []
    for ex in batch:
        img = ex["image"]  # PIL Image
        raw_text = ocr_extract_text(img)
        table_text = ocr_to_table_text(raw_text)
        raw_texts.append(raw_text)
        table_texts.append(table_text)

    # ------------------------------
    # 3b. Build batch prompts
    # ------------------------------
    messages_batch = []
    for ex, table_text in zip(batch, table_texts):
        prompt = build_prompt(table_text, ex["query"])
        messages_batch.append([{"role": "user", "content": prompt}])

    # ------------------------------
    # 3c. Tokenize batch
    # ------------------------------
    inputs = tokenizer.apply_chat_template(
        messages_batch,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_dict=True,
        return_tensors="pt",
    ).to(qwen_model.device)

    # ------------------------------
    # 3d. Generate batch answers
    # ------------------------------
    with torch.no_grad():
        outputs = qwen_model.generate(
            **inputs,
            max_new_tokens=60,
            do_sample=False
        )

    # ------------------------------
    # 3e. Decode batch
    # ------------------------------
    preds = tokenizer.batch_decode(
        outputs[:, inputs["input_ids"].shape[-1]:],
        skip_special_tokens=True
    )

    # ------------------------------
    # 3f. Evaluate batch
    # ------------------------------
    for ex, raw_text, table_text, pred in zip(batch, raw_texts, table_texts, preds):
        question = ex["query"]
        gt_list = ex["label"]

        pred = clean_prediction(pred)
        pred_norm = normalize_text(pred)

        exact = False
        relaxed = False

        for gt in gt_list:
            gt_norm = normalize_text(str(gt))
            if pred_norm == gt_norm:
                exact = True
                relaxed = True
                break
            if relaxed_numeric_match(pred_norm, gt_norm):
                relaxed = True

        if exact:
            exact_correct += 1
        if relaxed:
            relaxed_correct += 1
        total += 1

        results.append({
            "question": question,
            "ground_truth": gt_list,
            "ocr_text": raw_text,
            "table_text": table_text,
            "prediction": pred,
            "exact_match": exact,
            "relaxed_match": relaxed
        })

# ------------------------------
# 4. Final metrics
# ------------------------------
exact_acc = exact_correct / total
relaxed_acc = relaxed_correct / total

print("\n==============================")
print("CHART-TO-TABLE BASELINE RESULTS (50 samples)")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_acc:.4f}")
print(f"Relaxed Accuracy (±5%): {relaxed_acc:.4f}")

# ------------------------------
# 5. Preview first 5 results
# ------------------------------
for r in results[:5]:
    print(r["question"])
    print("GT:", r["ground_truth"])
    print("Pred:", r["prediction"])
    print("OCR Text (truncated):", r["ocr_text"][:100])
    print("Table Text (truncated):", r["table_text"][:100])
    print()

# ------------------------------
# 6. Save results
# ------------------------------
df = pd.DataFrame(results)
df.to_csv("chartqa_chart_to_table_results_50.csv", index=False)
# Out:
# CUDA available: True
# Device: NVIDIA L4
# Model device: cuda:0
# 100%|██████████| 480/480 [39:47<00:00,  4.97s/it]
# ==============================
# CHART-TO-TABLE BASELINE RESULTS (50 samples)
# ==============================
# Total samples: 1920
# Exact Accuracy: 0.0000
# Relaxed Accuracy (±5%): 0.0156
# What's the color of graph with 56 as the highest value?
# GT: ['Blue']
# Pred: The question asks: *"What's the color of the graph with 56 as the highest value?"*
# OCR Text (truncated): 34 26 29 28 Germanyityityis U.S. 56<sep/> 5.6 천 천
# Table Text (truncated): 34 | 26 | 29 | 28 | Germanyityityis | U.S. | 56<sep/> | 5.6 | 천 | 천
#
# In which year the difference between blue and green graph 1?
# GT: ['2018']
# Pred: The question asks: *"In which year the difference between blue and green graph 1?"*
# OCR Text (truncated): 34 26 29 28 Germanyityityis U.S. 56<sep/> 5.6 천 천
# Table Text (truncated): 34 | 26 | 29 | 28 | Germanyityityis | U.S. | 56<sep/> | 5.6 | 천 | 천
#
# What does the blue line represent?
# GT: ['Not too much/not at all']
# Pred: The provided table contains only the repeated label "총" (which means "total" in Korean) and does not include any data points, colors, or descriptions of lines (such as a blue line). Since there is no visual chart or additional context (like axis labels, legends, or descriptions of
# OCR Text (truncated): 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총
# Table Text (truncated): 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총
#
# What is the max value of blue line?
# GT: ['0.72']
# Pred: The table provided consists only of the repeated value "총" (which means "total" in Korean), and there are no numerical values or data points to determine a maximum value for a "blue line."
# OCR Text (truncated): 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총 총
# Table Text (truncated): 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총 | 총
#
# What's the percentage of respondents who say Job is a top priority for the president and Congress in 2016?
# GT: ['68']
# Pred: To find the percentage of respondents who say "Job is a top priority" for the president and Congress in 2016, we need to analyze the given data
# OCR Text (truncated): 48 48 49 49 49 49 49 49 36 36 36 36 36 36 36 36 36 36
# Table Text (truncated): 48 | 48 | 49 | 49 | 49 | 49 | 49 | 49 | 36 | 36 | 36 | 36 | 36 | 36 | 36 | 36 | 36 | 36

# %% [markdown]
# ## SOTAs

# %%
# ============================
# 2️⃣ Imports
# ============================
from transformers import DonutProcessor, VisionEncoderDecoderModel
from PIL import Image
import torch
from datasets import load_dataset

# ============================
# 3️⃣ Load pretrained UniChart ChartQA
# ============================
model_name = "ahmed-masry/unichart-chartqa-960"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = VisionEncoderDecoderModel.from_pretrained(model_name).to(device)
processor = DonutProcessor.from_pretrained(model_name)

# ============================
# 4️⃣ Load a small subset of ChartQA (first 25 samples)
# ============================
dataset = load_dataset("HuggingFaceM4/ChartQA")["val"]#.select(range(25))
dataset = [dict(ex) for ex in dataset]


# ============================
# 5️⃣ Helper function: run inference
# ============================
def run_chartqa_inference(image_or_path, question):
    input_prompt = f"<chartqa> {question} <s_answer>"

    # Accept either a path or a PIL.Image
    if isinstance(image_or_path, str):
        image = Image.open(image_or_path).convert("RGB")
    else:
        image = image_or_path.convert("RGB")

    decoder_input_ids = processor.tokenizer(
        input_prompt, add_special_tokens=False, return_tensors="pt"
    ).input_ids
    pixel_values = processor(image, return_tensors="pt").pixel_values

    outputs = model.generate(
        pixel_values.to(device),
        decoder_input_ids=decoder_input_ids.to(device),
        max_length=model.decoder.config.max_position_embeddings,
        early_stopping=True,
        pad_token_id=processor.tokenizer.pad_token_id,
        eos_token_id=processor.tokenizer.eos_token_id,
        use_cache=True,
        num_beams=4,
        bad_words_ids=[[processor.tokenizer.unk_token_id]],
        return_dict_in_generate=True,
    )
    sequence = processor.batch_decode(outputs.sequences)[0]
    # clean up the token artifacts
    sequence = sequence.replace(processor.tokenizer.eos_token, "").replace(
        processor.tokenizer.pad_token, ""
    )
    if "<s_answer>" in sequence:
        sequence = sequence.split("<s_answer>")[1].strip()
    return sequence


# ============================
# 6️⃣ Run baseline on first 25 samples
# ============================
exact_correct = 0
relaxed_correct = 0

for i, example in enumerate(dataset):
    image_path = example["image"]  # adjust if using local files
    question = example["query"]
    gt_answer = example["label"][0]  # assume single-answer GT

    try:
        pred_answer = run_chartqa_inference(image_path, question)
    except Exception as e:
        pred_answer = ""
        print(f"[WARN] Error on sample {i}: {e}")

    # exact match
    if pred_answer.lower() == gt_answer.lower():
        exact_correct += 1

    # relaxed match (numerical ±5% if float, else substring match)
    try:
        gt_val = float(gt_answer)
        pred_val = float(pred_answer)
        if abs(pred_val - gt_val) / max(gt_val, 1e-6) <= 0.05:
            relaxed_correct += 1
    except:
        # fallback: substring match
        if gt_answer.lower() in pred_answer.lower():
            relaxed_correct += 1

    print(f"Sample {i+1}: Q: {question} | GT: {gt_answer} | Pred: {pred_answer}")

total = len(dataset)
print("==============================")
print("CHART-TO-CHARTQA BASELINE RESULTS (first 25 samples)")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_correct/total:.4f}")
print(f"Relaxed Accuracy: {relaxed_correct/total:.4f}")
# Out:
# Loading weights:   0%|          | 0/484 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie decoder.model.decoder.embed_tokens.weight to decoder.lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Sample 1: Q: What's the color of graph with 56 as the highest value? | GT: Blue | Pred: Red
# Sample 2: Q: In which year the difference between blue and green graph 1? | GT: 2018 | Pred: 2018
# Sample 3: Q: What does the blue line represent? | GT: Not too much/not at all | Pred: Great deal/fair amount
# Sample 4: Q: What is the max value of blue line? | GT: 0.72 | Pred: 71
# Sample 5: Q: What's the percentage of respondents who say Job is a top priority for the president and Congress in 2016? | GT: 68 | Pred: 68
# Sample 6: Q: Which line has the lowest value of 71%? | GT: Economy | Pred: jobs
# Sample 7: Q: What is the unfavourable value in 2014? | GT: 64 | Pred: 64
# Sample 8: Q: What is the median value of favourable line in the graph? | GT: 40 | Pred: 40
# Sample 9: Q: Which answer response has the highest value on this graph? | GT: Disapprove | Pred: Disapprove
# Sample 10: Q: How many data points on the disapprove line are above 50? | GT: 2 | Pred: 2
# Sample 11: Q: Which indicator remains all time lowest from Dec. 2008 to Sep. 2011? | GT: Mostly good news | Pred: [Dec, Jul]
# Sample 12: Q: How much value of 'Mostly bad news' increased from Jan. 2011 to Sept. 2011? | GT: 37 | Pred: 2
# Sample 13: Q: When does the red line reach the peak? | GT: 44538 | Pred: 2009
# Sample 14: Q: What's the total sum of peak points of all three lines? | GT: 155 | Pred: 143
# Sample 15: Q: When does the yellow line reach the peak? | GT: 44207 | Pred: 2011
# Sample 16: Q: What's the total sum of peak points of green and red lines? | GT: 87 | Pred: 91
# Sample 17: Q: What's the lowest value of yellow line? | GT: 19 | Pred: 1
# Sample 18: Q: What's the difference of value of highiest value of red and lowest value of green line? | GT: 79 | Pred: 80
# Sample 19: Q: What is the colour of oppose in the graph? | GT: Light blue | Pred: Red
# Sample 20: Q: How many times there is 44 value in the Favor? | GT: 3 | Pred: 1
# Sample 21: Q: What is the percentage of people who are dissatisfied with Spain's democracy? | GT: 68 | Pred: 68
# Sample 22: Q: What is the ratio of people who are dissatisfied and satisfied with Spain's democracy? | GT: 2.125 | Pred: 0.043055556
# Sample 23: Q: Is the Pie chart divided into 3 segment? | GT: Yes | Pred: Yes
# Sample 24: Q: IS the value of No more then sum of Yes and Dk? | GT: Yes | Pred: No
# Sample 25: Q: What is the percentage of Iraqi dependents citizen? | GT: 0.12 | Pred: 0.19
# Sample 26: Q: What is the total percentage of Afghan applicants and Iraqi applicants? | GT: 0.34 | Pred: 0.49
# Sample 27: Q: Is the color of 53% segment light green? | GT: No | Pred: Yes
# Sample 28: Q: What's the ratio of Lean Republican segment and Republican segment? | GT: 0.7358 | Pred: 0.043055556
# Sample 29: Q: What segment represent by dark grey color? | GT: Both | Pred: Dark green
# Sample 30: Q: What is the percentage of both and don't know? | GT: [4, 9] | Pred: [12, 4]
# Sample 31: Q: What's the value of leftmost bar in the bottom? | GT: 12 | Pred: 12
# Sample 32: Q: What is the largest value of dark green bar? | GT: 0.92 | Pred: 0.69
# Sample 33: Q: Which country data analysed here? | GT: cuba | Pred: Less
# Sample 34: Q: What is the maximum value of dark brown bar? | GT: 7 | Pred: 47
# Sample 35: Q: What's the percentage of very important bar for healthy eating habits? | GT: 0.72 | Pred: 72
# Sample 36: Q: What's the average of green bar median and light blue bar median? | GT: 17 | Pred: 69.5
# Sample 37: Q: What does dark blue bar represents? | GT: Very Important | Pred: Somewhat important
# Sample 38: Q: What's the average value of all dark blue bars? | GT: 62.75 | Pred: 69.5
# Sample 39: Q: What does the color green indicate? | GT: Support | Pred: [Approve, Support]
# Sample 40: Q: What is the difference between the longest and the shortest green bar? | GT: 7 | Pred: 42
# Sample 41: Q: Which country has the highest percentage value of "a lot"? | GT: Kenya | Pred: Poland
# Sample 42: Q: What is the maximum value of "a lot" among countries? | GT: 0.69 | Pred: 69
# Sample 43: Q: How many bars are there in the graph? | GT: 2 | Pred: 2
# Sample 44: Q: What is the total sum of both the bars? | GT: 7.81 | Pred: 8.5
# Sample 45: Q: What's the value of United States? | GT: 0.124 | Pred: 12.4
# Sample 46: Q: What's the average value of Canada, Belgium and France? | GT: 0.0277 | Pred: 2.715
# Sample 47: Q: What is the death rate in the age group 5-14 years old? | GT: 0.0034 | Pred: 0.34
# Sample 48: Q: Find the median value of all the bars? | GT: 0.68 | Pred: 0.688
# Sample 49: Q: Which place shows the highest death rate? | GT: Grenada | Pred: Grenada
# Sample 50: Q: Is the value of death rate in Denmark more then Croatia? | GT: No | Pred: Yes
# Sample 51: Q: How many categories are there in the chart? | GT: 3 | Pred: 4
# Sample 52: Q: What's the average of two smallest bar? | GT: 70.535 | Pred: 37.715
# Sample 53: Q: How many bars are there in the graph? | GT: 2 | Pred: 2
# Sample 54: Q: What is the total add up value of Both the bars? | GT: 59 | Pred: 58
# Sample 55: Q: What denotes the light blue color bar? | GT: United States | Pred: Switzerland
# Sample 56: Q: What's the average value of all bars in the chart? | GT: 126.41 | Pred: 4.715
# Sample 57: Q: What does the value 2122 represent? | GT: Incidence | Pred: Incidence
# Sample 58: Q: What is the difference in the value between Incidence and Prevalence? | GT: 1092 | Pred: 1122
# Sample 59: Q: Which age group has the highest value? | GT: 20-24 years old | Pred: 20-24 years old
# Sample 60: Q: Find the average of the percentage value of bars greater than 1? | GT: 1.608 | Pred: 0.168
# Sample 61: Q: Which state shows the highest fertility rate? | GT: Malawi | Pred: Malawi
# Sample 62: Q: Is the value of Malawi greater then sum of Netherlands and Africa? | GT: Yes | Pred: Yes
# Sample 63: Q: What is the value of the largest bar? | GT: 1715 | Pred: 1715
# Sample 64: Q: What is the difference between the largest bar and the smallest bar? | GT: 1654 | Pred: 1612
# Sample 65: Q: Which country has its value 5.97%? | GT: India | Pred: India
# Sample 66: Q: Find the total percentage of the three countries having values lower than India? | GT: 0.07 | Pred: 1.85
# Sample 67: Q: What is the value of longest bar? | GT: 96 | Pred: 96
# Sample 68: Q: How many bars have value less then 1? | GT: 5 | Pred: 2
# Sample 69: Q: Which country represent by pink bar? | GT: Ethiopia | Pred: Ethiopia
# Sample 70: Q: What is the difference between red and blue bar? | GT: 0.56 | Pred: 0.21
# Sample 71: Q: How many response options are below 150 n mi? | GT: 2 | Pred: 2
# Sample 72: Q: What is the average of '24 hours' and '48 hours'? | GT: 105.45 | Pred: 0.855
# Sample 73: Q: Which year mentioned in the heading of the chart? | GT: 1911 | Pred: 1911
# Sample 74: Q: How many times political competition data bigger than political participation? | GT: 7.02 | Pred: 4
# Sample 75: Q: Find the value of green bar? | GT: 1.45 | Pred: 180000
# Sample 76: Q: How many times green bar greater than Agriculture bar? | GT: 8.53 | Pred: 0.16875
# Sample 77: Q: What is the value shown for Australia? | GT: 0.4368 | Pred: 0.4368
# Sample 78: Q: What is the average of bottom three bars? | GT: 38.08 | Pred: 36.11
# Sample 79: Q: What is color of the Age-standardized? | GT: cyan | Pred: gray
# Sample 80: Q: What is the value of the 50-69 years old? | GT: 8.88 | Pred: 8.88
# Sample 81: Q: The value is 40.49, find the category? | GT: Kidney cancer | Pred: 410.7
# Sample 82: Q: How many times stomach cancer bigger than Kidney cancer data? | GT: 10.13 | Pred: 410.3
# Sample 83: Q: Which two places mentioned in the chart? | GT: [Madagascar, Central Europe] | Pred: [Madagascar, Central Europe]
# Sample 84: Q: How much times Madagascar greater than Central europe data? | GT: 32 | Pred: 4
# Sample 85: Q: What is the average maize yield in Syria? | GT: 3.251 | Pred: 3.25
# Sample 86: Q: Find the ratio of highest value and average of two lowest values? | GT: 1.841359773 | Pred: 2.715
# Sample 87: Q: What is Female-to-male ratio to time devoted to unpaid care work in Italy? | GT: 3.37 | Pred: 3.37
# Sample 88: Q: What is the average of the values lower than 3 and greater than 2? | GT: 2.445 | Pred: 2.715
# Sample 89: Q: What is the value of largest bar? | GT: 396 | Pred: 396
# Sample 90: Q: Is the add up value of Comoros,Nicargua,Australia,Belgium is gretaer then Laos? | GT: No | Pred: Yes
# Sample 91: Q: Which country has longest bar? | GT: Malta | Pred: Malta
# Sample 92: Q: What is the difference of Sweden and Malta? | GT: 7.49 | Pred: 0.07
# Sample 93: Q: How many colors are used in the graph? | GT: 1 | Pred: 5
# Sample 94: Q: What is the sum of largest and smallest bar? | GT: 159.85 | Pred: 160.87
# Sample 95: Q: How many colors are represented in the bar?? | GT: 5 | Pred: 5
# Sample 96: Q: What is the difference between Industry employment percentage in Iran and Kenya?? | GT: 26.38 | Pred: 0.25
# Sample 97: Q: Which place shows the highest cases of guinea worm? | GT: South Sudan | Pred: South Sudan
# Sample 98: Q: Is the sum of Senegal and Central African Republic more then Chad? | GT: No | Pred: No
# Sample 99: Q: How many colors are represented in the bar?? | GT: 8 | Pred: 10
# Sample 100: Q: What's the average value of first two bars in the chart?? | GT: 0.33 | Pred: 0.07
# Sample 101: Q: What group has the highest death rate? | GT: 70+ years old | Pred: 70+ years old
# Sample 102: Q: What is the difference between the death rates of 5-14 ears old with the death rate of 70+ years old? | GT: 272.62 | Pred: 262.75
# Sample 103: Q: Which country represented by Brown bar? | GT: Bangladesh | Pred: Andorra
# Sample 104: Q: What is the difference of largest and smallest bar? | GT: 409.13 | Pred: 311
# Sample 105: Q: Which country is indicated by the middle bar? | GT: Namibia | Pred: Namibia
# Sample 106: Q: Total values of all the three bars lower than .02? | GT: No | Pred: Yes
# Sample 107: Q: Which country has longest bar? | GT: Iraq | Pred: Iraq
# Sample 108: Q: Does the sum of smallest two bar is greater then the largest bar? | GT: No | Pred: No
# Sample 109: Q: What is the color of Mexico bar? | GT: Pink | Pred: Purple
# Sample 110: Q: What is the sum of smallest three bar? | GT: 3.7 | Pred: 0.6
# Sample 111: Q: What is the highest value in the bar graph? | GT: 23 | Pred: 23
# Sample 112: Q: Is Croatia global hunger index extremely alarminhg? | GT: No | Pred: Yes
# Sample 113: Q: How many colors are used in the graph? | GT: 1 | Pred: 7
# Sample 114: Q: What is the average of smallest two bars? | GT: 13 | Pred: 13.5
# Sample 115: Q: What denotes the green color bar ?? | GT: Sub-Saharan Africa | Pred: Central and Southern Asia
# Sample 116: Q: Find out the average of the bottom three countries ?? | GT: 0.0593 | Pred: 5.4
# Sample 117: Q: What country is represented by the Red bar? | GT: Libya | Pred: Libya
# Sample 118: Q: What is the difference between the largest bar and the smallest bar? | GT: 0.092 | Pred: 0.8
# Sample 119: Q: Which animal is represented by longest bar? | GT: Cattle | Pred: Cattle
# Sample 120: Q: What is difference of value of Paddy rice and Wheat? | GT: 6.5 | Pred: 0.6
# Sample 121: Q: How many region are shown in the chart? | GT: 7 | Pred: 5
# Sample 122: Q: What the difference in value between Asia and Caribbean? | GT: 1.18 | Pred: 0.04
# Sample 123: Q: What is the death rate from drug use disorders in Thailand? | GT: 0.77 | Pred: 0.77
# Sample 124: Q: Is the average value of Andean Latin America and Cambodia more than the value of Thailand? | GT: Yes | Pred: Yes
# Sample 125: Q: What is the number of undernourished people in Southern Asia as of 2000 ( in millions)? | GT: 264.5 | Pred: 264.5
# Sample 126: Q: What is the sum of undernourished people in Low Income economies and Sub-Saharan Africa combined (in millions)? | GT: 341.9 | Pred: 329.8
# Sample 127: Q: What is the value of Pink bar? | GT: 21524 | Pred: 10527
# Sample 128: Q: Does the Saudi Arabia and Australasia has same value ? | GT: No | Pred: Yes
# Sample 129: Q: What does the color orange represent? | GT: Estimated number of polio cases | Pred: Red
# Sample 130: Q: How many bar has the same value ? | GT: 2 | Pred: 2
# Sample 131: Q: What does the lowest bar represent? | GT: Pre-demographic dividend | Pred: Pre-demographic dividend
# Sample 132: Q: What is the difference of value  between Malaysia and Barbados? | GT: 10.18 | Pred: 0.21
# Sample 133: Q: How many age group are shown the graph? | GT: 6 | Pred: 12
# Sample 134: Q: What is the sum of lowest bar and top most bar in the grap? | GT: 61.23 | Pred: 61.23
# Sample 135: Q: What is the % of people who are undernourished in Southern Asia as of 2000? | GT: 18.2 | Pred: 18.2
# Sample 136: Q: Is the sum of the % of people who are undernourished in Southern Asia and Eastern Asia more than that in Sub-Saharan Africa? | GT: Yes | Pred: Yes
# Sample 137: Q: What is the % of people who are worried about losing their job in Cyprus? | GT: 58.79 | Pred: 58.79
# Sample 138: Q: What is the difference in % between Poland and Australia for people who are worried about losing their job? | GT: 17.05 | Pred: 0.15
# Sample 139: Q: In which country has the smallest value? | GT: Angola | Pred: South Sudan
# Sample 140: Q: How many bars with the equal value in the bar graph? | GT: 2 | Pred: 5
# Sample 141: Q: Which country recorded highest percentage in the chart ? | GT: Tanzania | Pred: Tanzania
# Sample 142: Q: How many times Tanzania data bigger than Ethiopia data ? | GT: 3.5 | Pred: 4.4
# Sample 143: Q: What's the value of smallest bar? | GT: 0.96 | Pred: 0.96
# Sample 144: Q: Does the difference of iDA only and Upper middle income is equal to the value of smallest bar? | GT: No | Pred: No
# Sample 145: Q: Which country has highest Pig meat yields ? | GT: United States | Pred: United States
# Sample 146: Q: What is the difference in Green and Purple bar? | GT: 5 | Pred: 0.6
# Sample 147: Q: What's the value of largest bar? | GT: 270827 | Pred: 270827
# Sample 148: Q: Does the sum of smallest two bar is equal to 3rd smallest bar? | GT: No | Pred: No
# Sample 149: Q: How many colors are there in the graph? | GT: 4 | Pred: 4
# Sample 150: Q: Does the sum of smallest two bar is greater then then the value of largest bar? | GT: Yes | Pred: Yes
# Sample 151: Q: What is the value of middle bar ? | GT: 81.71 | Pred: 81.71
# Sample 152: Q: What is ratio between Primary school and upper secondary ? | GT: 0.3493 | Pred: 0.43055556
# Sample 153: Q: what is orange bar represents ? | GT: Europe | Pred: Europe
# Sample 154: Q: what is the sum of africa and pacific ? | GT: 0.07 | Pred: 6
# Sample 155: Q: Which color bar resembles the name of a fruit? | GT: orange | Pred: purple
# Sample 156: Q: What is the value of the Child Labor bar? | GT: 0.193 | Pred: 21.4
# Sample 157: Q: In chart Middle bar represents what ? | GT: Madagascar | Pred: Madagascar
# Sample 158: Q: What is the average of all the numbers ? | GT: 1.55 | Pred: 1.48
# Sample 159: Q: Which is the highest percentage of the value? | GT: 0.405 | Pred: 40.5
# Sample 160: Q: What is the value of the United Kingdom? | GT: 0.354 | Pred: 35.4
# Sample 161: Q: What is the color of the shortest bar? | GT: Gray | Pred: gray
# Sample 162: Q: Would the combined homicide rate for the 5-14 and Under 5's be bigger than All Ages? | GT: No | Pred: No
# Sample 163: Q: How many lines are shown in the chart? | GT: 6 | Pred: 5
# Sample 164: Q: When does the gap between Nigeria and India reach the largest value? | GT: 2021 | Pred: 2021
# Sample 165: Q: Which country has the highest value in 1979? | GT: Iceland | Pred: Ukraine
# Sample 166: Q: Which country has the smallest fluctuations in the chart? | GT: South Korea | Pred: South Korea
# Sample 167: Q: In which year was the death rate due to unsafe water sources is lowest in the Maldives? | GT: 2000 | Pred: 2000
# Sample 168: Q: Which country saw the higher death rate due to unsafe water sources from 1990 to 2000 between Palestine and Norway? | GT: Palestine | Pred: Maldives
# Sample 169: Q: The pink line in the chart belongs to which country data? | GT: France | Pred: France
# Sample 170: Q: Find out Which country data is stable for the entire 3 years? | GT: France | Pred: Germany
# Sample 171: Q: When did the line reach its peak? | GT: 1998 | Pred: 1998
# Sample 172: Q: During which period does the line have the greatest increase? | GT: 1998 | Pred: 1998
# Sample 173: Q: Which two countries are being compared in the given line graph? | GT: [Africa, Northern America] | Pred: [World, Africa, Northern America]
# Sample 174: Q: Which of the following countries saw a higher demand in education over the given years, Africa or North America? | GT: Africa | Pred: Africa
# Sample 175: Q: What does Orange line represents? | GT: Urban | Pred: Urban
# Sample 176: Q: What's the difference in the value of highest percentage value given in the chart and the percentage points where two lines cross? | GT: 0.3 | Pred: 5
# Sample 177: Q: In which year the share of youth not in education is maximum� in Laos? | GT: 2017 | Pred: 2017
# Sample 178: Q: In how many years the share of youth not in education is more than 20 %? | GT: 4 | Pred: 4
# Sample 179: Q: In which year the commercial bank branches are maximum in Senegal? | GT: 2009 | Pred: 2009
# Sample 180: Q: In how many years does the number of commercial bank branches are greater than 30 in Montenegro? | GT: 3 | Pred: 3
# Sample 181: Q: What age group does the Red bar Show in the graph? | GT: 15-17 years | Pred: 15-17 years
# Sample 182: Q: Which among Red and Grey bar has the highest value in the year 2000? | GT: Red | Pred: 15-17 years
# Sample 183: Q: Which year saw the maximum change in the death rate due to tuberculosis in the age group 70+ years old in Seria? | GT: 2010 | Pred: 1990
# Sample 184: Q: Which age group saw the maximum change in the death rate due to tuberculosis over the years? | GT: Under-5s | Pred: 70+ years old
# Sample 185: Q: Which year recorded the least daily hempseed production in Europe? | GT: 1990 | Pred: 1970
# Sample 186: Q: Which of the following saw the higher daily hempseed production over the years, Europe or Europe, Western? | GT: Europe | Pred: Europe
# Sample 187: Q: How many years shows the Unemployment rate in the graph? | GT: 9 | Pred: 5
# Sample 188: Q: In which year did the color green and orange bar intersect? | GT: 2005 | Pred: 1996
# Sample 189: Q: Which age group recorded the highest daily rates of bipolar disorder in Argentina? | GT: 15-49 years old | Pred: 15-49 years old
# Sample 190: Q: How many age groups are mentioned in the given graph? | GT: 4 | Pred: 5
# Sample 191: Q: How many regions have more than 60 % proportions that applied for accreditation? | GT: 1 | Pred: 4
# Sample 192: Q: Which region saw the highest proportion of accreditation over the given years? | GT: Southern Asia | Pred: Southern Asia
# Sample 193: Q: In which year the share of people having access to clean fuel for cooking is maximum in Bosnia and Herzegovina? | GT: 2013 | Pred: 2013
# Sample 194: Q: Which of the following countries has had higher access to clean fuels for cooking over the years, Latvia or Belize? | GT: Latvia | Pred: Latvia
# Sample 195: Q: Which year recorded the highest prevalence of Anemia in women in the Bahamas? | GT: 1990 | Pred: 1990
# Sample 196: Q: Which of the following countries recorded the higher prevalence of Anemia in women over the years, Zambia or Bahamas? | GT: Zambia | Pred: Zambia
# Sample 197: Q: Which year recorded the lowest mortality rate in the Caribbean? | GT: 1990 | Pred: 1990
# Sample 198: Q: In how many years has the mortality rate is greater than 10% in the Caribbean? | GT: 3 | Pred: 3
# Sample 199: Q: Which year does Czechia point? | GT: 1992 | Pred: 1992
# Sample 200: Q: Between which, two years does the bar shows the lowest value? | GT: [1965, 1970] | Pred: [1962, 1972]
# Sample 201: Q: Which year recorded the maximum urban population living in slums in Kenya? | GT: 2000 | Pred: 2000
# Sample 202: Q: Which year recorded the least urban population living in slums in Kenya? | GT: 1990 | Pred: 1990
# Sample 203: Q: What does country does the orange line represent? | GT: Tajikistan | Pred: Latvia
# Sample 204: Q: what is the difference in Alcohol and drug use disorders in Tajikistan between 2000 and 2009? | GT: 0.005 | Pred: 0.4
# Sample 205: Q: How many drugs are shown in the graph? | GT: 4 | Pred: 5
# Sample 206: Q: When does the gap between Opioids and Cocaine reach the peak? | GT: 2014 | Pred: 2014
# Sample 207: Q: In which year the home production time by male age group 25-54 is minimum? | GT: 1930 | Pred: 1980
# Sample 208: Q: In how many years the weekly production time by age group 55-64 is greater than 25 hours? | GT: 31 | Pred: 3
# Sample 209: Q: Which country is represented by the blue color line? | GT: Russia | Pred: Russia
# Sample 210: Q: Which country has a higher share of the population using safely managed drinking water over the years? | GT: Bosnia and Herzegovina | Pred: Bosnia and Herzegovina
# Sample 211: Q: Which year recorded the highest suicide rates by males in Portugal? | GT: 1996 | Pred: 1996
# Sample 212: Q: Which of the following sex recorded the higher suicide rates over the years, male or female? | GT: Male | Pred: male
# Sample 213: Q: Which country is represented by the red color line? | GT: United States Virgin Islands | Pred: Kiribati
# Sample 214: Q: In how many countries the concentration of particulate matter is found to be more than 20 micrograms? | GT: 2 | Pred: 4
# Sample 215: Q: How many countries are represented on the graph? | GT: 2 | Pred: 2
# Sample 216: Q: How many years are Greece's population rate below 35% | GT: 1 | Pred: 2
# Sample 217: Q: Which country is represented by the red line? | GT: Kenya | Pred: Kenya
# Sample 218: Q: Which country has an all-time lower share of children younger than 5 who are underweight for their age? | GT: Peru | Pred: Togo
# Sample 219: Q: Which country is represented by the given line graph? | GT: Niger | Pred: Niger
# Sample 220: Q: In which year did the line graph saw its lowest dip? | GT: 2013 | Pred: 2013
# Sample 221: Q: Is the starting value of the red graph the lowest value? | GT: Yes | Pred: Yes
# Sample 222: Q: Is the value of the blue graph constantly increasing? | GT: Yes | Pred: Yes
# Sample 223: Q: Which country has the highest rise in the number of poultry birds from 1961 to 1990? | GT: Cuba | Pred: Cuba
# Sample 224: Q: In which year, the middle line (Uruguay) is lowest? | GT: 1975 | Pred: 1970
# Sample 225: Q: Which area/region is represented by the upper line? | GT: Bahrain | Pred: Bahrain
# Sample 226: Q: Which bar has the lowest value? | GT: Lesotho | Pred: Lesotho
# Sample 227: Q: Is the National GDP value lower than 7 billion in 1955? | GT: Yes | Pred: Yes
# Sample 228: Q: In which year National GDP value crossed 20 billion? | GT: 1974 | Pred: 1974
# Sample 229: Q: Which gender is represented by the red color line? | GT: Male | Pred: Female
# Sample 230: Q: Which year recorded the highest number of cases of killing of male Journalists? | GT: 2018 | Pred: 2018
# Sample 231: Q: Which line has an all-time 'high share of the population with severe food insecurity than other lines? | GT: Low income | Pred: Low income
# Sample 232: Q: Which line has the slightest change in the share of the population with severe food insecurity? | GT: Eastern Asia | Pred: Low income
# Sample 233: Q: Is the highest value of Myanmar greater than 30000? | GT: Yes | Pred: Yes
# Sample 234: Q: Is the Myanmar graph value in 1997 is the median value of this graph? | GT: Yes | Pred: Yes
# Sample 235: Q: Which country is used in the line graph? | GT: Guatemala | Pred: Guatemala
# Sample 236: Q: Which year it is in peak? | GT: 2006 | Pred: 2006
# Sample 237: Q: Which region is represented by the given line graph? | GT: South Eastern Asia | Pred: South Eastern Asia
# Sample 238: Q: Which year recorded the lowest value Red List Index? | GT: 2019 | Pred: 2019
# Sample 239: Q: Which country is represented by the given line graph? | GT: Jamaica | Pred: Jamaica
# Sample 240: Q: In how many years, the share of government expenditure is more than 10% in Jamaica? | GT: 4 | Pred: 2
# Sample 241: Q: What is the value of drug use in the year 1990? | GT: 1000 | Pred: 1039
# Sample 242: Q: What is the approximate difference of values in the year 1990? | GT: 900 | Pred: 221
# Sample 243: Q: Which country is featured in the graph? | GT: Canada | Pred: Canada
# Sample 244: Q: After which year does the line have the sharpest decrease? | GT: 2008 | Pred: 2003
# Sample 245: Q: Which country is represented in this graph? | GT: Australia | Pred: Australia
# Sample 246: Q: In what year did Australia reach its peak? | GT: 1980 | Pred: 2005
# Sample 247: Q: How many regions are represented? | GT: 5 | Pred: 5
# Sample 248: Q: How many regions saw increases? | GT: 5 | Pred: 5
# Sample 249: Q: In which year, the value of the red graph peaked? | GT: 2009 | Pred: 2009
# Sample 250: Q: In which year was the difference between the prevalence of obesity in adult males maximum in Sri Lanka and Czechia? | GT: 2009 | Pred: 2009
# Sample 251: Q: In which year, the value of Employment in the agriculture graph peaked? | GT: 1999 | Pred: 2005
# Sample 252: Q: For how many years, the value of the "Employment in services" graph smaller than 60%? | GT: 13 | Pred: 2
# Sample 253: Q: Which country is represented by blue color line? | GT: Korea | Pred: Korea
# Sample 254: Q: Which year recorded the least number of Caesarean sections in the Czech Republic? | GT: 2006 | Pred: 2006
# Sample 255: Q: Is the crude oil import price greater than 25$/barrel in 1984? | GT: Yes | Pred: Yes
# Sample 256: Q: In how many years has the crude oil import price smaller than 15$/barrel? | GT: 1 | Pred: 2
# Sample 257: Q: What's the percentage of Trump voters who are against Biden? | GT: 24 | Pred: 24
# Sample 258: Q: What's the ratio of Trump voters who are against Biden and Biden voters who are for Biden? | GT: 0.340972222 | Pred: 0.043055556
# Sample 259: Q: What's the percentage value of the topmost green bar? | GT: 60 | Pred: 60
# Sample 260: Q: What's the ratio of Never/Rarely and Occasionally/Frequently in Luo? | GT: 0.085416667 | Pred: 0.0423611111
# Sample 261: Q: What's the lowest value of the light blue bar? | GT: 8 | Pred: 15
# Sample 262: Q: What's the average of all the bars in Germany? | GT: 24.25 | Pred: 0.4
# Sample 263: Q: 18, 22, _, 20, find the missed data? | GT: 40 | Pred: 20
# Sample 264: Q: What's the ratio(A:B) of the largest value and the rightmost value in WHO category? | GT: 0.084027778 | Pred: 0.042361111
# Sample 265: Q: What percent of US adults who say their state governments policies to control the spread of coronavirus are influence A Fair amount by evidence from public health experts ? | GT: 40 | Pred: 0.43
# Sample 266: Q: Is the A Great deal value of the state government more than Federal government ? | GT: Yes | Pred: Yes
# Sample 267: Q: What's the highest value of gray bar? | GT: 61 | Pred: 61
# Sample 268: Q: What's the median value of the green bars? | GT: 19 | Pred: 14
# Sample 269: Q: What's the value of the green bar for 65+ age group? | GT: 58 | Pred: 28
# Sample 270: Q: How many values of green bar exceed 30? | GT: 3 | Pred: 2
# Sample 271: Q: What's the leftmost value of bar in "All adults" category? | GT: 48 | Pred: 48
# Sample 272: Q: What's the median value of all the bars in rightside? | GT: 50 | Pred: 46.5
# Sample 273: Q: What is youtube Trust data? | GT: 17 | Pred: 17
# Sample 274: Q: What is the average of all the Trust Data? | GT: 248.83 | Pred: 0.168
# Sample 275: Q: How many consumers feel A lot confident about what they are buying? | GT: 37 | Pred: 0.37
# Sample 276: Q: What�s the difference between the maximum and the minimum value in the last bar? | GT: 49 | Pred: 0.16
# Sample 277: Q: What color represent Confidence in the bar? | GT: Green | Pred: gray
# Sample 278: Q: Which region has the highest value that has No confidence in Mohammad bin Salman? | GT: Israel | Pred: Israel
# Sample 279: Q: which color shows As in the bar? | GT: gray | Pred: gray
# Sample 280: Q: What is the total of Jordan in More, As, and less? | GT: 99 | Pred: 0.168
# Sample 281: Q: 46, 43, 41 which data is missed? | GT: 47 | Pred: [Be held accountable by govt, Use users']
# Sample 282: Q: Is the sum of the highest value of navy blue bar and median of light blue bar greater than 100? | GT: No | Pred: Yes
# Sample 283: Q: What's the percentage of men who have "Should NOT be made legal" opinions? | GT: 30 | Pred: 30
# Sample 284: Q: Count the number of yellow bars with 30 values? | GT: 3 | Pred: No
# Sample 285: Q: What percent of the Labour group shows the economic situation is Bad in Uk? | GT: 60 | Pred: 60
# Sample 286: Q: What is the total of Bad and Good in the Remain? | GT: 100 | Pred: 100
# Sample 287: Q: How many of them say in West Germany that religion is very important in their lives? | GT: 27 | Pred: 0.27
# Sample 288: Q: What is the Ration of Somewhat in West Germany and East Germany? | GT: 1.393055556 | Pred: 0.27
# Sample 289: Q: What's the value of the blue bar in France? | GT: 76 | Pred: 76
# Sample 290: Q: Is the median of green bars greater than the median of the blue bar? | GT: No | Pred: Yes
# Sample 291: Q: What's the maximum value in the brightest yellow bar? | GT: 53 | Pred: 38
# Sample 292: Q: What's the difference in the value of the total number of persons who want to improve the way government works and who have not? | GT: 33 | Pred: 0.09
# Sample 293: Q: How many people in total think Chinese growth is a good thing for the US? | GT: 50 | Pred: 0.05
# Sample 294: Q: What's the average percentage for people between 18-49 who think Chinese growth is a good thing for the US? | GT: 53.5 | Pred: 0.56
# Sample 295: Q: How many rows of data are there | GT: 7 | Pred: 4
# Sample 296: Q: For all Dem/Lean Dem, what is the difference in opinions between supporting 50s and the oldest age studied as the best age to be a president | GT: 44 | Pred: 4
# Sample 297: Q: What's the percentage of white who oppose the death penalty for persons convicted of murder? | GT: 34 | Pred: 34
# Sample 298: Q: What's the ratio of medians of Oppose and Favor bars? | GT: 0.554166667 | Pred: 0.0423611111
# Sample 299: Q: What's the percentage value of the blue bar in Greece? | GT: 87 | Pred: 87
# Sample 300: Q: Is the median of the green bar greater than the largest value of the gray bar? | GT: Yes | Pred: Yes
# Sample 301: Q: What's the percentage of adults who are not concerned about identity theft? | GT: 16 | Pred: 16
# Sample 302: Q: What's the sum of all the gray bars whose value exceeds 15? | GT: 72 | Pred: 0.6
# Sample 303: Q: Which color represents Republican? | GT: Red | Pred: gray
# Sample 304: Q: What is the total of Republicans and Democrats in 2010? | GT: 87 | Pred: 120
# Sample 305: Q: What's the lowest value of Mostly good bars? | GT: 21 | Pred: 21
# Sample 306: Q: What's the median of all the right-side bars? | GT: 35 | Pred: 37.5
# Sample 307: Q: What's the NET value of the All Teens bar? | GT: 57 | Pred: 32
# Sample 308: Q: How many bars have a Very worried value is greater than its Somewhat Worried value? | GT: 1 | Pred: 2
# Sample 309: Q: How much does Italy's government's responsibility had the highest percentage? | GT: 0.74 | Pred: 0.74
# Sample 310: Q: What is the difference between the government's responsibility of Sweden to the UK? | GT: 0.04 | Pred: 0
# Sample 311: Q: What's the value of the 1st Longest bar in the graph? | GT: 25 | Pred: 25
# Sample 312: Q: What's the total sum of immigrants of South and West? | GT: 8 | Pred: 32
# Sample 313: Q: What does the Dark blue bar represent? | GT: A great deal | Pred: A great deal
# Sample 314: Q: Is the sum of all values of "None at all" is greater than the largest value of the dark blue bar? | GT: No | Pred: Yes
# Sample 315: Q: Which county plays the least important role in the world than it did 10 years ago? | GT: UK | Pred: [UK, France]
# Sample 316: Q: What is the sum of the least and highest value in the graph? | GT: 0.91 | Pred: 91
# Sample 317: Q: How many colors are shown in the graph? | GT: 4 | Pred: 4
# Sample 318: Q: Is the Very value in All voters more than Somewhat in All voters? | GT: No | Pred: Yes
# Sample 319: Q: What's the color of the Rightmost bar? | GT: Green | Pred: gray
# Sample 320: Q: Is the add-up the value of all Green segments is greater than the sum of all Dark blue segments? | GT: Yes | Pred: Yes
# Sample 321: Q: Is the color of the middle bars gray? | GT: Yes | Pred: Yes
# Sample 322: Q: Is the median of green bars greater than the largest value of the gray bar? | GT: No | Pred: Yes
# Sample 323: Q: What percent of White believes that race or ethnicity should be a major factor in college admission decisions? | GT: 4 | Pred: 4
# Sample 324: Q: How many shades of Green does a bar show? | GT: 2 | Pred: 2
# Sample 325: Q: In the chart, Too little 69 percentage refers to? | GT: Protect water quality of lakes, rivers, streams | Pred: Yes
# Sample 326: Q: As per the study, if you ask 500 people,� how many will say Protect air quality- too little and Too much? | GT: 360 | Pred: 0.63
# Sample 327: Q: What's the value of the rightmost bar in the middle? | GT: 50 | Pred: 37
# Sample 328: Q: What's the ratio of two bars in the middle (A: B)? | GT: 0.042361111 | Pred: 0.0423611111
# Sample 329: Q: What is the average between men and women? | GT: 67.5 | Pred: 64.5
# Sample 330: Q: What is the average of everyone who is winning more than they are losing? | GT: 30.4 | Pred: 0.625
# Sample 331: Q: How many % of respondents from Mexico have confidence in President Trump? | GT: 5 | Pred: 0.05
# Sample 332: Q: What is the ratio of people who have confidence in President Trump and those who don't in Venezuela? | GT: 0.884722222 | Pred: 0.0423611111
# Sample 333: Q: What percent of High school or less says the country Has been about right when it comes to giving women equal rights with men? | GT: 46 | Pred: 46
# Sample 334: Q: Is the sum of Bachelors more than the sum of Women? | GT: Yes | Pred: Yes
# Sample 335: Q: Who says Good more to the question? | GT: General public | Pred: Bad
# Sample 336: Q: How many times good is more than bad in General Public? | GT: 2.62 | Pred: 0.43755
# Sample 337: Q: In which country, 16% of human rights organizations are primarily dedicated to promoting the interest of foreign groups? | GT: Kenya | Pred: Kenya
# Sample 338: Q: Take the median of orange bars, multiply it by 3, is the result greater than the smallest value of the green bar? | GT: No | Pred: Yes
# Sample 339: Q: How many colors are in the bar?? | GT: 3 | Pred: 2
# Sample 340: Q: What is the total distribution of adversary and serious problems?? | GT: 65 | Pred: 0.43
# Sample 341: Q: What's the value of the top rightmost bar? | GT: 7 | Pred: 15
# Sample 342: Q: What's the ratio of the smallest Gen X bar and second smallest Silent/Greatest bar? | GT: 1.00625 | Pred: 0.04236111111
# Sample 343: Q: What's the percentage of U.S. adults who oppose more fracking? | GT: 53 | Pred: 53
# Sample 344: Q: Take the sum of the two smallest green bars, is it greater than the smallest blue bar? | GT: No | Pred: Yes
# Sample 345: Q: What's the value of the rightmost first bar from the bottom? | GT: 8 | Pred: 24
# Sample 346: Q: What's the average of all the uppermost bars (round to one decimal place)? | GT: 32.7 | Pred: 0.168
# Sample 347: Q: What input situation is represented by the biggest bar | GT: Click on links to news stories | Pred: Sometimes
# Sample 348: Q: What is the sum of the median often opinion and the biggest net opinion | GT: 88 | Pred: 40.5
# Sample 349: Q: What represents the two bars in the chart?? | GT: [Oppose, Favor] | Pred: [Oppose, Favor]
# Sample 350: Q: What is the ratio between oppose and favor distribution for a ban on high-capacity ammunition clips?? | GT: 1.993055556 | Pred: 0.0423611111
# Sample 351: Q: What is the value of Very opinion in Aug 2016? | GT: 49 | Pred: 49
# Sample 352: Q: What's the ratio of the largest bar and the sum of the two smallest bars? | GT: 2.588888889 | Pred: 0.43055556
# Sample 353: Q: What's the value of the largest bar in Total? | GT: 53 | Pred: 53
# Sample 354: Q: How many bars have a value below 40? | GT: 6 | Pred: 2
# Sample 355: Q: What's the percentage of the total population that favors weakening the EU? | GT: 65 | Pred: 65
# Sample 356: Q: What are the top three groups that favor weakening the EU? | GT: [50+, Men, Secondary education or less] | Pred: Total
# Sample 357: Q: What's the percentage of Black saying it is very important that their children earn a college degree? | GT: 17 | Pred: 17
# Sample 358: Q: Take "Extremely important" bar median and "Very important" bar median, divide larger value by smaller value, what's the result(only integer value)? | GT: 1 | Pred: 3
# Sample 359: Q: How many colors are represented in the bar?? | GT: 3 | Pred: 5
# Sample 360: Q: What's the average of the two smallest green bar?? | GT: 0.5 | Pred: 60.5
# Sample 361: Q: How many categories are there in the chart?? | GT: 8 | Pred: 10
# Sample 362: Q: What's the average of the two smallest bar?? | GT: 38.5 | Pred: 39.5
# Sample 363: Q: Which two country is compared here? | GT: [Czech Republic, New Zealand] | Pred: [New Zealand, Czech Republic]
# Sample 364: Q: How many times  New Zealand greater than Czech Republic? | GT: 3.0659 | Pred: 43.5
# Sample 365: Q: Which country is represented by longest bar? | GT: Japan | Pred: Japan
# Sample 366: Q: What's the total add up value of japan and Colombia? | GT: 51.7 | Pred: 50
# Sample 367: Q: Which country has the largest bar? | GT: Denmark | Pred: Denmark
# Sample 368: Q: How many countries have over 4 broad money? | GT: 2 | Pred: 4
# Sample 369: Q: What is the value Exports in Hungary? | GT: 4.5 | Pred: 4.5
# Sample 370: Q: Is the average value of these two bars greater than 3? | GT: No | Pred: Yes
# Sample 371: Q: How many colors are represented in the bar? | GT: 2 | Pred: 2
# Sample 372: Q: What's the average of two smallest bar? | GT: 40.9 | Pred: 40.4
# Sample 373: Q: Which country represented by Blue bar? | GT: Romania | Pred: Latvia
# Sample 374: Q: What is the average of all the three bars? | GT: 8.3 | Pred: 11.3
# Sample 375: Q: What's the color of smallest bar? | GT: Red | Pred: Red
# Sample 376: Q: What is the average value of both the bars? | GT: 6.3 | Pred: 6.4
# Sample 377: Q: What is the color of the highest bar? | GT: green | Pred: purple
# Sample 378: Q: What is the difference in Inward FDI stocks between Spain and Poland? | GT: 0.42 | Pred: 0.4
# Sample 379: Q: What's the value of blue bar? | GT: 29 | Pred: 11.6
# Sample 380: Q: What's the add up value of Australia and France? | GT: 40.6 | Pred: 0.336
# Sample 381: Q: How many color bars are there in the Graph? | GT: 3 | Pred: 3
# Sample 382: Q: Is the difference of value of Austria and Ireland bar is greater then the value of United States bar? | GT: No | Pred: Yes
# Sample 383: Q: What color represent Norway? | GT: purple | Pred: purple
# Sample 384: Q: How many countries have long term interest rates over 5 percent? | GT: 3 | Pred: 4
# Sample 385: Q: Which country is represented by RED bar? | GT: Austria | Pred: Greece
# Sample 386: Q: Does the difference in the value of largest two bars is half the value of smallest bar? | GT: No | Pred: No
# Sample 387: Q: What is the color of the lowest value in the graph? | GT: Blue | Pred: gray
# Sample 388: Q: What is the difference in the value of China and Tanzania? | GT: 0.4 | Pred: 0.6
# Sample 389: Q: How many color are shown in the chart? | GT: 4 | Pred: 4
# Sample 390: Q: Is the difference value of DAC Countries is more then Sweden? | GT: Yes | Pred: Yes
# Sample 391: Q: What does the red bar represent? | GT: Russia | Pred: Argentina
# Sample 392: Q: What's the difference between two bars? | GT: 0.044 | Pred: 0.05
# Sample 393: Q: Which country has the highest value of Reading performance? | GT: Finland | Pred: Finland
# Sample 394: Q: Is the median value of all bars greater than 500? | GT: No | Pred: Yes
# Sample 395: Q: What is the Real GDP long-term forecast for Poland? | GT: 1.26M | Pred: 1.26
# Sample 396: Q: Is the average of the two bar values as shown in the graph greater than 1? | GT: No | Pred: Yes
# Sample 397: Q: Is there any value 50.2 in this graph? | GT: Yes | Pred: Yes
# Sample 398: Q: Is the median value of all the bars greater than 50.2? | GT: No | Pred: Yes
# Sample 399: Q: Which country has the highest interest rate? | GT: Korea | Pred: Korea
# Sample 400: Q: How many countries fall below 6%? | GT: 2 | Pred: 2
# Sample 401: Q: Which is the top place in the chart? | GT: School | Pred: School
# Sample 402: Q: How many places in the chart have over 50% value? | GT: 3 | Pred: 4
# Sample 403: Q: What does the yellow bar represent? | GT: Distrust | Pred: Trust
# Sample 404: Q: What is the difference between maximum and minimum values of trust and distrust respectively? | GT: 41 | Pred: 12
# Sample 405: Q: What % of UK residents believe in the use of force to defend Allies in case they are attacked by Russia? | GT: 0.49 | Pred: 49
# Sample 406: Q: In how many countries do more than 45% of the respondents believe that their country should defend allies in case they are attacked by Russia? | GT: 6 | Pred: 2
# Sample 407: Q: How many support Euro in Spain? | GT: 0.71 | Pred: 0.03
# Sample 408: Q: What is the difference in the support of Euro between Spain and Italy? | GT: 0.15 | Pred: 0.2
# Sample 409: Q: What is Republican data in Feb 2015 for mostly good? | GT: [12,63,23] | Pred: Republican
# Sample 410: Q: What is the ratio between  Mostly good and Mostly bad in Democrat Feb 2015? | GT: 3.22222 | Pred: 0.04236111111
# Sample 411: Q: What is total personal remittances paid by India (in million dollar)? | GT: 350.83 | Pred: 650.83
# Sample 412: Q: Is the sum of two smallest bar greater than largest bar? | GT: No | Pred: Yes
# Sample 413: Q: Which country is represented by brown color bar? | GT: Cameroon | Pred: Low Income Food deficit countries
# Sample 414: Q: What is the average of coffee yields by Congo and Cameroon? | GT: 0.51 | Pred: 0.5
# Sample 415: Q: What is the projected number of children per women in the Fast Track scenario? | GT: 1.92 | Pred: 1.92
# Sample 416: Q: What is the sum in the the projected number of children per women in all scenarios? | GT: 6.33 | Pred: 6.4
# Sample 417: Q: What country has the highest share that disagree that vaccines are important? | GT: Namibia | Pred: Namibia
# Sample 418: Q: What is the average among the two contries in the share that disagree that vaccines are important? | GT: 1.105 | Pred: 0.915
# Sample 419: Q: What country have the loewst suicide rate? | GT: Niger | Pred: Niger
# Sample 420: Q: Is the suicide rate in Ukraine higer then the sum of the other four countries? | GT: No | Pred: Yes
# Sample 421: Q: Which country has the largest bar? | GT: Nepal | Pred: Nepal
# Sample 422: Q: Is the sum of Australasia and Switzerland larger than Nepal? | GT: No | Pred: Yes
# Sample 423: Q: How many color bar are shown the graph? | GT: 5 | Pred: 5
# Sample 424: Q: What is the total value of two least bar? | GT: 20.34 | Pred: 16.5
# Sample 425: Q: Which price is represented by brown color bar? | GT: Northwest Europe marker price | Pred: Japan coking coal import cif price
# Sample 426: Q: What is the average price of Japan coking coal import cif and Japan steam spot cif? | GT: 177.625 | Pred: 136.21
# Sample 427: Q: What is red line represents? | GT: Germany | Pred: Germany
# Sample 428: Q: Which country data shows a down trend? | GT: United States | Pred: Norway
# Sample 429: Q: In which year the percentage of daily smokers peaked in Luxembourg? | GT: 2019 | Pred: 2018
# Sample 430: Q: In which year, the percentage of daily smokers in Luxembourg is greater than Ireland? | GT: 2019 | Pred: 2018
# Sample 431: Q: Which country is represented by blue color line? | GT: Belgium | Pred: Czech Republic
# Sample 432: Q: How many countries have more than 40k enterprises over the given years? | GT: 2 | Pred: 2
# Sample 433: Q: How many countries are shown in the chart? | GT: 2 | Pred: 2
# Sample 434: Q: When does the gap between two countries become biggest? | GT: 2012 | Pred: 2015
# Sample 435: Q: Which two countries are being compared in the given graph? | GT: [Argentina, Indonesia] | Pred: [Argentina, Indonesia]
# Sample 436: Q: Which year recorded the highest fertility rate in Indonesia? | GT: 1976 | Pred: 1976
# Sample 437: Q: Which country is represented by blue color line? | GT: Estonia | Pred: Latvia
# Sample 438: Q: Which country has highest government production costs over the given years? | GT: France | Pred: France
# Sample 439: Q: Which country is in middle of Canad and Slovenia? | GT: United States | Pred: United States
# Sample 440: Q: Is the median value of Slovenia data points greater than 40? | GT: Yes | Pred: Yes
# Sample 441: Q: Which country has the lowest household net worth over the years? | GT: Estonia | Pred: Estonia
# Sample 442: Q: In which year the value of red line is smaller than blue line? | GT: 2009 | Pred: 2011
# Sample 443: Q: Is Austria represented by purple dotted line? | GT: Yes | Pred: Yes
# Sample 444: Q: Which country recorded smallest labour productivity value over the years? | GT: Slovenia | Pred: Slovenia
# Sample 445: Q: In which country has the highest peak in this bar graph? | GT: Switzerland | Pred: Switzerland
# Sample 446: Q: What is the difference between the highest value and lowest value of switzerland? | GT: 4 | Pred: 4
# Sample 447: Q: What country have the lowest value in national insurance market share? | GT: Iceland | Pred: Iceland
# Sample 448: Q: Between what years Netherlands had the highest change in the value of national insurance market share? | GT: 2015 | Pred: 2004
# Sample 449: Q: Which country is represented by the given line graph? | GT: Canada | Pred: Canada
# Sample 450: Q: Which year recorded the lowest net childcare costs in Canada? | GT: 2019 | Pred: 2019
# Sample 451: Q: In what year Poland achieved the highest value in pension funds' assets? | GT: 2013 | Pred: 2013
# Sample 452: Q: In what year Belgium passed Poland in the value of pension funds' assets? | GT: 2019 | Pred: 2019
# Sample 453: Q: Which country does the blue line represent? | GT: Canada | Pred: Poland
# Sample 454: Q: When does the gap between Poland and Denmark become smallest? | GT: 2017 | Pred: 2011
# Sample 455: Q: Which country shows highest rise in the Short term interest rates from 1995 to 2000? | GT: Brazil | Pred: Brazil
# Sample 456: Q: Which four countries data is compared in this graph? | GT: [Brazil, Slovenia, Switzerland, Japan] | Pred: [Swegian, Brazil]
# Sample 457: Q: Which country is represented by blue color line? | GT: New Zealand | Pred: Israel
# Sample 458: Q: Between which two years , the GDP of New Zealand is maximum? | GT: 2009 | Pred: 2009
# Sample 459: Q: Which country is represented by blue color line? | GT: France | Pred: Australia
# Sample 460: Q: At how much points does lines representing Australia and France crosses each other? | GT: 1 | Pred: 1
# Sample 461: Q: Which country does the red line refer to? | GT: Poland | Pred: Poland
# Sample 462: Q: When does the difference between two countries become largest? | GT: 2019 | Pred: 2019
# Sample 463: Q: Which country does the red line represent? | GT: Netherlands | Pred: Chile
# Sample 464: Q: During which time did tourism receipts and spending in Netherlands decline? | GT: 2014 | Pred: [2015, 2016]
# Sample 465: Q: Who has the most oscars out of the the actors listed | GT: Katharine Hepburn | Pred: Katharine Hepburn
# Sample 466: Q: How many oscars do jack nicolson and meryl streep have combined? | GT: 6 | Pred: 3
# Sample 467: Q: How many distribution are there in the pie chart? | GT: 8 | Pred: 10
# Sample 468: Q: Take highest percentage and lowest percentage (leave 0), add it and divide it by 2, what is the result? | GT: 17.5 | Pred: 4
# Sample 469: Q: What is very important percentage? | GT: 12 | Pred: 12
# Sample 470: Q: Assume total respondent as 1000, what is the sum of person will tell 'very Important' and 'important'? | GT: 620 | Pred: 100
# Sample 471: Q: Find out , who is referred in blue? | GT: 620 | Pred: 0.9
# ...
# Sample 1781: Q: How many daily active users did Douyin have in comparison to the period prior to the epidemic? | GT: 81.92 | Pred: 81.92
# Sample 1782: Q: How many people were killed in motor vehicle accidents in Luxembourg in 2010? | GT: 32 | Pred: 32
# Sample 1783: Q: How many road fatalities occurred in Luxembourg in 2009? | GT: 48 | Pred: 48
# Sample 1784: Q: How many wins have the New England Patriots had during the postseason? | GT: 37 | Pred: 37
# Sample 1785: Q: What was the value of UK exports to the EU in 2019? | GT: 294.3 | Pred: 294.3
# Sample 1786: Q: How much British pounds worth of goods and services did the UK export to the EU in 2015? | GT: 225.5 | Pred: 225.5
# Sample 1787: Q: Which region had the highest number of cases of coronavirus? | GT: Lombardy | Pred: Lombardy
# Sample 1788: Q: How much did adjusted U.S. retail e-commerce sales amount to in the first quarter of 2021? | GT: 215035 | Pred: 216037
# Sample 1789: Q: How many TV households were in the Middle East and Africa in 2012? | GT: 65 | Pred: 65
# Sample 1790: Q: How many metric tons of fresh vegetables did India produce in 2019? | GT: 132.03 | Pred: 132.03
# Sample 1791: Q: What was the benchmark index of commercial rents during the 1st quarter of 2020? | GT: 116.23 | Pred: 116.16
# Sample 1792: Q: What was the value of imports of synthetic resins and rubbers in Canada in 2019? | GT: 8624 | Pred: 8624
# Sample 1793: Q: How much did the real hourly earnings of all employees in the United States decrease in May 2021? | GT: 0.2 | Pred: 0.2
# Sample 1794: Q: What was the payroll of the Red Sox in 2020? | GT: 95 | Pred: 95
# Sample 1795: Q: What was the second most popular newspaper in the UK? | GT: The Times | Pred: The Guardian
# Sample 1796: Q: What was the most popular newspaper in the UK in the fourth quarter of 2020? | GT: Metro | Pred: Metro
# Sample 1797: Q: What was the second most popular newspaper in the UK? | GT: The Guardian | Pred: The Guardian
# Sample 1798: Q: Which country had the largest loss of sales due to counterfeit sporting goods? | GT: France | Pred: France
# Sample 1799: Q: How much did the French sporting goods sector lose in 2015? | GT: 82 | Pred: 82
# Sample 1800: Q: What was the value of private equity investments as of 2016? | GT: 87.23 | Pred: 87.23
# Sample 1801: Q: What was the total value of private equity investments in 2007? | GT: 443.81 | Pred: 443.81
# Sample 1802: Q: What was Brazil's national gross income per person in the previous year? | GT: 9130 | Pred: 9140
# Sample 1803: Q: What was Brazil's gross income per capita in 2019? | GT: 9130 | Pred: 9130
# Sample 1804: Q: How much money did travel and tourism directly contribute to the North East Asian economy in 2017? | GT: 573.7 | Pred: 573.7
# Sample 1805: Q: How much money did Snap spend on sales and marketing in 2015? | GT: 555.47 | Pred: 27.22
# Sample 1806: Q: How many international tourists and non-resident Indians arrived in India in 2019? | GT: 17.91 | Pred: 17.91
# Sample 1807: Q: What percentage of GDP did the national debt of the Philippines amount to in 2020? | GT: 47.07 | Pred: 47.07
# Sample 1808: Q: Who is the career passing leader of the Philadelphia Eagles? | GT: Donovan McNabb | Pred: Donovan McNabb
# Sample 1809: Q: How many enterprises made games and toys in the Netherlands in 2017? | GT: 432 | Pred: 432
# Sample 1810: Q: How many points does Ronan O'Gara have for the Irish national rugby team? | GT: 93 | Pred: 93
# Sample 1811: Q: Who holds the record for most points scored at the Rugby World Cup? | GT: Ronan O'Gara | Pred: Roman O'Gara
# Sample 1812: Q: What percentage of the Aosta Valley population had risky alcohol consumption? | GT: 23 | Pred: 23
# Sample 1813: Q: What was the total revenue of Bartlett Tree Experts in 2020? | GT: 352 | Pred: 352
# Sample 1814: Q: What was the inflation rate in the Central African Republic in 2020? | GT: 2.3 | Pred: 3.34
# Sample 1815: Q: What was Deutsche Telekom's revenue in Germany in 2020? | GT: 24.63 | Pred: 7.53
# Sample 1816: Q: What was the percentage of female managing directors working at Barclays in 2017? | GT: 14 | Pred: 14
# Sample 1817: Q: What was the production value of the Romanian textile manufacturing sector in 2015? | GT: 1286.2 | Pred: 1182.6
# Sample 1818: Q: What was the value of the Nashville Predators in dollars in 2020? | GT: 435 | Pred: 435
# Sample 1819: Q: What percentage of COVID-19 patients died after contracting the virus? | GT: 65.7 | Pred: 65.7
# Sample 1820: Q: What was the brand value of HSBC in 2015? | GT: 27.3 | Pred: 27.3
# Sample 1821: Q: How many dollars did Callaway Golf spend on research and development in 2020? | GT: 46.3 | Pred: 46.3
# Sample 1822: Q: How much was proposed for military crisis management in 2021? | GT: 59 | Pred: 319
# Sample 1823: Q: How much did the Defense Forces pay in 2021? | GT: 815 | Pred: 800
# Sample 1824: Q: What accounts for the largest part of the 2021 budget? | GT: HX Fighter Program | Pred: 2021
# Sample 1825: Q: What was the GDP of Massachusetts in dollars in the previous year? | GT: 519.96 | Pred: 519.96
# Sample 1826: Q: What was the GDP of Massachusetts in 2020? | GT: 500.24 | Pred: 500.24
# Sample 1827: Q: What was Egypt's birth rate per one thousand inhabitants in 2013? | GT: 28.52 | Pred: 28.18
# Sample 1828: Q: What was the crude birth rate in Egypt in 2019? | GT: 25.71 | Pred: 25.71
# Sample 1829: Q: What was Egypt's birth rate per one thousand inhabitants in 2013? | GT: 28.52 | Pred: 28.18
# Sample 1830: Q: What was Coca Cola's market share in Egypt in 2010? | GT: 32 | Pred: 32
# Sample 1831: Q: How many home runs has Frank Thomas hit? | GT: 448 | Pred: 448
# Sample 1832: Q: Who has hit the most home runs in Chicago White Sox franchise history? | GT: Frank Thomas | Pred: Frank Thomas
# Sample 1833: Q: What is the name of the Haitian youtube news channel? | GT: Tele Image Valerio Saint-Louis | Pred: Tele Image Valentin-Louis
# Sample 1834: Q: What is the name of the comedy channel in Haiti? | GT: Komedyen Lakay Official | Pred: LINE Douze
# Sample 1835: Q: How many views did Tele Image Valerio Saint-Louis have in Haiti as of March 2021? | GT: 83.02 | Pred: 83.02
# Sample 1836: Q: How many fans did the USA Today profile have on Facebook? | GT: 4824550 | Pred: 4824550
# Sample 1837: Q: How many dollars did Callaway Golf report in golf club sales in 2020? | GT: 787.1 | Pred: 788.7
# Sample 1838: Q: What is the estimated amount of eSports sponsorship and advertising spending in the United States in 2023? | GT: 634.03 | Pred: 634.03
# Sample 1839: Q: What was the estimated amount of sponsorship and advertising spending on the eSports market in 2017? | GT: 124.41 | Pred: 124.41
# Sample 1840: Q: What was the percentage of energy from renewable sources in Poland from 2006 to 2015? | GT: 6.9 | Pred: 6.9
# Sample 1841: Q: What was the market share of Zurich Insurance Group in 2019? | GT: 3.7 | Pred: 3.7
# Sample 1842: Q: For every male participant, how many females were in the labor force in Bangladesh in 2016? | GT: 0.53 | Pred: 0.53
# Sample 1843: Q: What was Zimbabwe's youth unemployment rate in 2020? | GT: 8.07 | Pred: 8.08
# Sample 1844: Q: What was Lloyds Banking Group's cost to income ratio in 2019? | GT: 48.5 | Pred: 48.5
# Sample 1845: Q: How many people lived in Region Nordjylland in 2021? | GT: 589936 | Pred: 720902
# Sample 1846: Q: How many people lived in Hovedstaden in the first quarter of 2021? | GT: 1846023 | Pred: 171350
# Sample 1847: Q: What was the franchise value of the Denver Broncos in 2020? | GT: 3200 | Pred: 3200
# Sample 1848: Q: What was the monthly CPI for lamb and goat meat in Italy at the beginning of the year 2015? | GT: 101.7 | Pred: 104.5
# Sample 1849: Q: What was the monthly CPI for lamb and goat meat in November 2020? | GT: 104.5 | Pred: 104.5
# Sample 1850: Q: How much money did the convenience store industry generate from fuel sales in 2011? | GT: 486.9 | Pred: 486.9
# Sample 1851: Q: How much did the 2016 Olympic Summer Games licensing revenue amount to? | GT: 31 | Pred: 31
# Sample 1852: Q: What percentage of vote shares did the Conservative Party gain? | GT: 5.5 | Pred: 5.5
# Sample 1853: Q: What percentage of e-commerce visits via tablet devices were converted into purchases in the second quarter of 2020? | GT: 3.32 | Pred: 3.32
# Sample 1854: Q: How many stores did Dillard's operate in 2020? | GT: 282 | Pred: 282
# Sample 1855: Q: What was Five Below's net sales per store a year earlier? | GT: 2.2 | Pred: 2.2
# Sample 1856: Q: What country had the largest Snapchat user base in the world? | GT: India | Pred: India
# Sample 1857: Q: How many users did Snapchat have in the United States as of April 2021? | GT: 108.65 | Pred: 108.65
# Sample 1858: Q: What percentage of white respondents said they see the Confederate flag as a symbol of racism? | GT: 25 | Pred: 25
# Sample 1859: Q: What was Kuwait's infant mortality rate per 1,000 live births in 2019? | GT: 6.8 | Pred: 6.8
# Sample 1860: Q: How many people committed suicide by throwing themselves in front of a train in 2006? | GT: 24 | Pred: 24
# Sample 1861: Q: How many dollars did Foot Locker generate in the United States in 2020? | GT: 5581 | Pred: 5581
# Sample 1862: Q: What percentage of the gross domestic product did Mexico spend in 2020? | GT: 29.12 | Pred: 29.12
# Sample 1863: Q: What was the lowest production of duck foie gras in 2017? | GT: 11519 | Pred: 11519
# Sample 1864: Q: How many ducks were euthanized due to the H5N8 virus? | GT: 11519 | Pred: 11519
# Sample 1865: Q: What was the average amount of duck foie gras produced in France between 2007 and 2015? | GT: 18602 | Pred: 19679.5
# Sample 1866: Q: How much money did Etsy invest in its advertising in 2016? | GT: 442.2 | Pred: 56.99
# Sample 1867: Q: What was the most frequently used social network in Canada? | GT: Instagram | Pred: Facebook
# Sample 1868: Q: What was the most frequently used social network in Canada? | GT: Facebook | Pred: Facebook
# Sample 1869: Q: How much did Alphabet spend on lobbying in 2020? | GT: 8.85 | Pred: 8.85
# Sample 1870: Q: How much did J.K. Rowling earn from June 2018 to June 2019? | GT: 92 | Pred: 92
# Sample 1871: Q: What was Vodafone Germany's EBITDA in 2020/21? | GT: 5.63 | Pred: 5.63
# Sample 1872: Q: What was the previous year's EBITDA? | GT: 5.08 | Pred: 5.08
# Sample 1873: Q: What percentage of Google's revenue was generated in the UK in 2015? | GT: 10 | Pred: 10
# Sample 1874: Q: Which country has the most markets? | GT: France | Pred: Germany
# Sample 1875: Q: What was the highest salary in the cruise industry in 2019? | GT: 9.93 | Pred: 9.93
# Sample 1876: Q: How much did the cruise industry pay in employee wages in 2009? | GT: 5.48 | Pred: 5.48
# Sample 1877: Q: How much was the expenses of the Green Bay Packers in 2017? | GT: 376.1 | Pred: 420.9
# Sample 1878: Q: What percentage of all legal abortions in Alabama were performed on Hispanic women in 2018? | GT: 5.1 | Pred: 5.1
# Sample 1879: Q: What was the import trade value of bamboo and rattan furniture in the United States in 2015? | GT: 21.07 | Pred: 21.07
# Sample 1880: Q: What was the import trade value of bamboo and rattan furniture between 2015 and 2016? | GT: 18.7 | Pred: 18.7
# Sample 1881: Q: How much did the import trade value of bamboo and rattan furniture increase between 2011 and 2016? | GT: 21.07 | Pred: 18.7
# Sample 1882: Q: What was the revenue from video analytics in 2015? | GT: 858 | Pred: 858
# Sample 1883: Q: What religion were about 116,000 Canadian citizens, permanent and non-permanent residents of Prince Edward Island identified as in 2011? | GT: Christian | Pred: Christian
# Sample 1884: Q: When did the value of gross written premiums by life insurance companies on the domestic market in Malta increase? | GT: 2012 | Pred: 2011
# Sample 1885: Q: What was the peak value of gross written premiums in Malta in 2018? | GT: 415 | Pred: 415
# Sample 1886: Q: What was the value of life insurance premiums in 2019? | GT: 378 | Pred: 378
# Sample 1887: Q: How many UCI beds were there in Mexico City in April of 2020? | GT: 453 | Pred: 891
# Sample 1888: Q: How many adult intensive care units were in Mexico City in April 2020? | GT: 891 | Pred: 891
# Sample 1889: Q: Which social media site accounted for 57.52 percent of all social media site visits in Canada in May 2021? | GT: Facebook | Pred: Facebook
# Sample 1890: Q: Who is the career touchdown leader of the Atlanta Falcons? | GT: Roddy White | Pred: Roddy White
# Sample 1891: Q: How many career touchdowns has Roddy White scored? | GT: 63 | Pred: 63
# Sample 1892: Q: What percentage of Rio 2016 viewers were women? | GT: 22 | Pred: 22
# Sample 1893: Q: What percentage of India's GDP did military expenditure amount to in 2019? | GT: 2.4 | Pred: 2.4
# Sample 1894: Q: What was Ethiopia's share in the global gross domestic product adjusted for Purchasing Power Parity in 2020? | GT: 0.22 | Pred: 0.22
# Sample 1895: Q: How much revenue did A.P. M ller - Maersk A/S generate from its ocean segment in 2020? | GT: 29.18 | Pred: 29.18
# Sample 1896: Q: How much money did pirates receive in ransom for the release of the oil tanker Savina Caylyn? | GT: 11.5 | Pred: 11.5
# Sample 1897: Q: Which beer brand topped the beer production volume in Germany in 2016? | GT: Krombacher | Pred: Kombacher
# Sample 1898: Q: How much did Manchester United's operating expenses in 2020 amount to? | GT: 645.88 | Pred: 645.88
# Sample 1899: Q: What percentage of the Dominican Republic's GDP would be lost as a result of the COVID-19 pandemic? | GT: 0.8 | Pred: 6.1
# Sample 1900: Q: What percentage of the Dominican Republic's GDP would be affected by the COVID-19 pandemic? | GT: 6.1 | Pred: 6.1
# Sample 1901: Q: What percentage of Netflix subscribers said they would keep the service if the monthly price increased by five dollars per month? | GT: 53 | Pred: 22
# Sample 1902: Q: Which candidate received the most donations from the oil and gas industry? | GT: Hillary Clinton | Pred: Marco Rubio
# Sample 1903: Q: When is the forecasted year with the highest consumption volume? | GT: 2020 | Pred: 2020
# Sample 1904: Q: What is the average annual consumption of biodiesel in OECD countries? | GT: 21759.24 | Pred: 20934
# Sample 1905: Q: In what year did the turnover of the retail sale of leisure products increase to 6.7 billion British pounds? | GT: 2017 | Pred: 2018
# Sample 1906: Q: What percentage of 17 year olds attended school? | GT: 93.3 | Pred: 93.3
# Sample 1907: Q: What percentage of 14 year olds were schooled in 2017-2018? | GT: 98.8 | Pred: 98.8
# Sample 1908: Q: What was Sweden's per capita gross domestic product in kronor in 2019? | GT: 488 | Pred: 488
# Sample 1909: Q: What was the value of the gross domestic product in Sweden in kronor in 2019? | GT: 488 | Pred: 488
# Sample 1910: Q: In what year did the per capita gross domestic product reach its highest value? | GT: 2019 | Pred: 2019
# Sample 1911: Q: What was the population of Eswatini in 2017? | GT: 1.1 | Pred: 1.09
# Sample 1912: Q: What was the inflation rate in Suriname in 2019? | GT: 4.39 | Pred: 3.84
# Sample 1913: Q: What was the share of consumers who wrote checks in 2018? | GT: 31 | Pred: 31
# Sample 1914: Q: How many specialised stores were there in the UK in March of 2020? | GT: 15 | Pred: 360
# Sample 1915: Q: Which country is the most active in CAR cell therapy trials? | GT: China | Pred: United States
# Sample 1916: Q: What was the most valuable British-Dutch oil and gas company in 2021? | GT: Shell | Pred: Shell
# Sample 1917: Q: What was the only brand in the top ten with headquarters outside of the UK? | GT: Shell | Pred: Shell
# Sample 1918: Q: What was the second most valuable oil and gas company in the UK in 2021? | GT: BP | Pred: BP
# Sample 1919: Q: Where did migrants arrive from January to December 2018? | GT: Pozzallo | Pred: Pozzullo
# Sample 1920: Q: Which country ranked second in the Italian migration chart? | GT: Lampedusa | Pred: Czechia
# ==============================
# CHART-TO-CHARTQA BASELINE RESULTS (first 25 samples)
# ==============================
# Total samples: 1920
# Exact Accuracy: 0.5422
# Relaxed Accuracy: 0.6521

# %% [markdown]
# ## Simple Baseline: CLIP --> LLM

# %%
import torch
from torch import nn
from PIL import Image
from datasets import load_dataset
from transformers import CLIPProcessor, CLIPModel, AutoTokenizer, AutoModelForCausalLM
from tqdm import tqdm

# 1️⃣ Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2️⃣ Load CLIP
clip_model_name = "openai/clip-vit-base-patch32"
clip_model = CLIPModel.from_pretrained(clip_model_name).to(device)
clip_processor = CLIPProcessor.from_pretrained(clip_model_name)

# 3️⃣ Load Qwen (frozen)
qwen_model_name = "Qwen/Qwen3-4B-Instruct-2507"
qwen_tokenizer = AutoTokenizer.from_pretrained(qwen_model_name)
qwen_model = AutoModelForCausalLM.from_pretrained(qwen_model_name, device_map="auto").to(device)
qwen_model.eval()
for param in qwen_model.parameters():
    param.requires_grad = False

# 4️⃣ Projection layer: CLIP embedding -> Qwen embedding
clip_embed_dim = clip_model.config.projection_dim
qwen_embed_dim = qwen_model.config.hidden_size
image_proj = nn.Linear(clip_embed_dim, qwen_embed_dim, device=device, dtype=qwen_model.dtype)
optimizer = torch.optim.Adam(image_proj.parameters(), lr=1e-4)

# 5️⃣ Load ChartQA val subset (first 25 for example)
dataset = load_dataset("HuggingFaceM4/ChartQA")["val"]#.select(range(25))
dataset = [dict(ex) for ex in dataset]

dataset_train = load_dataset("HuggingFaceM4/ChartQA")["train"]#.select(range(3000))
#dataset_train = [dict(ex) for ex in dataset_train]

# 6️⃣ Training: regress projected CLIP embedding to Qwen embedding of question
loss_fn = nn.MSELoss()
num_epochs = 5

for epoch in range(num_epochs):
    total_loss = 0
    for ex in tqdm(dataset_train, desc=f"Epoch {epoch+1}/{num_epochs}"):
        image_obj = ex["image"]
        question = ex["query"]

        # ---- CLIP image embedding ----
        if isinstance(image_obj, str):
            image = Image.open(image_obj).convert("RGB")
        else:
            image = image_obj.convert("RGB")

        clip_inputs = clip_processor(images=image, return_tensors="pt").to(device)
        with torch.no_grad():
            clip_output = clip_model.get_image_features(**clip_inputs)
            if isinstance(clip_output, torch.Tensor):
                clip_emb = clip_output
            elif hasattr(clip_output, "pooler_output"):
                clip_emb = clip_output.pooler_output
            elif hasattr(clip_output, "image_embeds"):
                clip_emb = clip_output.image_embeds
            else:
                raise ValueError("Cannot extract tensor from CLIP output")
        clip_emb = clip_emb.to(dtype=image_proj.weight.dtype, device=device)
        proj_emb = image_proj(clip_emb)  # [1, qwen_embed_dim]

        # ---- Qwen embedding of question ----
        token_ids = qwen_tokenizer(question, return_tensors="pt").input_ids.to(device)
        with torch.no_grad():
            qwen_embeddings = qwen_model.get_input_embeddings()(token_ids).mean(dim=1)  # average over tokens

        # ---- Compute loss & update projection ----
        loss = loss_fn(proj_emb, qwen_embeddings)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1} avg loss: {total_loss/len(dataset):.4f}")

# 7️⃣ Inference: use projected image embedding as prefix for question
def run_clip_qwen(image_obj, question):
    if isinstance(image_obj, str):
        image = Image.open(image_obj).convert("RGB")
    else:
        image = image_obj.convert("RGB")

    clip_inputs = clip_processor(images=image, return_tensors="pt").to(device)
    with torch.no_grad():
        clip_output = clip_model.get_image_features(**clip_inputs)
        if isinstance(clip_output, torch.Tensor):
            clip_emb = clip_output
        elif hasattr(clip_output, "pooler_output"):
            clip_emb = clip_output.pooler_output
        elif hasattr(clip_output, "image_embeds"):
            clip_emb = clip_output.image_embeds
        clip_emb = clip_emb.to(dtype=image_proj.weight.dtype, device=device)
        proj_emb = image_proj(clip_emb).unsqueeze(1)  # [1,1,qwen_embed_dim]

    # Text embeddings
    token_ids = qwen_tokenizer(f"Question: {question}, You are a chart question-answering assistant. Use the chart to respond to the question with the final answer only, no explanations.", return_tensors="pt").input_ids.to(device)
    text_emb = qwen_model.get_input_embeddings()(token_ids).to(dtype=image_proj.weight.dtype, device=device)

    # Concatenate image + text
    inputs_embeds = torch.cat([proj_emb, text_emb], dim=1)

    # Generate answer
    with torch.no_grad():
        outputs = qwen_model.generate(
            inputs_embeds=inputs_embeds,
            max_new_tokens=32,
            num_beams=4,
            eos_token_id=qwen_tokenizer.eos_token_id,
        )
    answer = qwen_tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer

# 8️⃣ Test baseline
exact_correct = 0
relaxed_correct = 0

for i, ex in enumerate(dataset):
    image_obj = ex["image"]
    question = ex["query"]
    gt_answer = ex["label"][0]

    try:
        pred_answer = run_clip_qwen(image_obj, question)
    except Exception as e:
        pred_answer = ""
        print(f"[WARN] Error on sample {i}: {e}")

    # Exact match
    if pred_answer.lower() == gt_answer.lower():
        exact_correct += 1

    # Relaxed match: numeric closeness (5%) or substring
    try:
        gt_val = float(gt_answer)
        pred_val = float(pred_answer)
        if abs(pred_val - gt_val) / max(gt_val, 1e-6) <= 0.05:
            relaxed_correct += 1
    except:
        if gt_answer.lower() in pred_answer.lower():
            relaxed_correct += 1

    print(f"Sample {i+1}: Q: {question} | GT: {gt_answer} | Pred: {pred_answer}")

total = len(dataset)
print("\n==============================")
print("CLIP → Qwen PROJECTION RESULTS")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_correct/total:.4f}")
print(f"Relaxed Accuracy: {relaxed_correct/total:.4f}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# The image processor of type `CLIPImageProcessor` is now loaded as a fast processor by default, even if the model checkpoint was saved with a slow processor. This is a breaking change and may produce slightly different outputs. To continue using the slow processor, instantiate this class with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/727 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00
# ...
# Sample 1855: Q: What was Five Below's net sales per store a year earlier? | GT: 2.2 | Pred:  Do not make up data. Do not say "Insufficient data". Do not say "I cannot answer that". Do not say "Not enough information". Do
# Sample 1856: Q: What country had the largest Snapchat user base in the world? | GT: India | Pred:  Do not make up data. Do not say "Based on the chart...". Do not say "The country with the largest Snapchat user base is...". Do
# Sample 1857: Q: How many users did Snapchat have in the United States as of April 2021? | GT: 108.65 | Pred:  Do not make up data. If the data is not in the chart, say "Data not available in chart".
#
# Number of Snapchat Users in the United States (
# Sample 1858: Q: What percentage of white respondents said they see the Confederate flag as a symbol of racism? | GT: 25 | Pred:  Do not make up data. Do not say "Based on the chart...". Just answer the question. The chart shows the percentage of white respondents who said they
# Sample 1859: Q: What was Kuwait's infant mortality rate per 1,000 live births in 2019? | GT: 6.8 | Pred:  The chart has the following columns: Country, Year, Infant Mortality Rate (per 1,000 live births), Life Expectancy at Birth (
# Sample 1860: Q: How many people committed suicide by throwing themselves in front of a train in 2006? | GT: 24 | Pred:  Do not make up data or statistics. If the data is not available in the chart, respond with "Data not available in chart".
#
# Thought: The question is
# Sample 1861: Q: How many dollars did Foot Locker generate in the United States in 2020? | GT: 5581 | Pred:  Each row in the chart represents a year. Each column in the chart represents a country. The values in the cells are the revenue in millions of dollars. The
# Sample 1862: Q: What percentage of the gross domestic product did Mexico spend in 2020? | GT: 29.12 | Pred:  Do not make up data. Do not say "The chart does not show". Do not say "I don't know". Do not say "Insufficient data
# Sample 1863: Q: What was the lowest production of duck foie gras in 2017? | GT: 11519 | Pred:  Avoid making up data or inferences. If the data is not available in the chart, respond with "Data not available".
#
# Chart:
# | Year | Duck
# Sample 1864: Q: How many ducks were euthanized due to the H5N8 virus? | GT: 11519 | Pred:  Each row in the chart represents a different country. The columns are: Country, Number of birds affected, Number of birds died, Number of birds euthanized
# Sample 1865: Q: What was the average amount of duck foie gras produced in France between 2007 and 2015? | GT: 18602 | Pred:  The chart shows the average amount of duck foie gras produced in France between 2007 and 2015. The average amount of duck
# Sample 1866: Q: How much money did Etsy invest in its advertising in 2016? | GT: 442.2 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available".
#
# Chart: None
# Answer: Data not available
# Sample 1867: Q: What was the most frequently used social network in Canada? | GT: Instagram | Pred:  Do not make up data. Do not say "Based on the chart...". Do not say "The most frequently used social network in Canada is...". The
# Sample 1868: Q: What was the most frequently used social network in Canada? | GT: Facebook | Pred:  Do not make up data. Do not say "Based on the chart...". Do not say "The most frequently used social network in Canada is...". The
# Sample 1869: Q: How much did Alphabet spend on lobbying in 2020? | GT: 8.85 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available".
#
# We are given a question about Alphabet's lobbying
# Sample 1870: Q: How much did J.K. Rowling earn from June 2018 to June 2019? | GT: 92 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available".
#
# Chart:
# | Name | 20
# Sample 1871: Q: What was Vodafone Germany's EBITDA in 2020/21? | GT: 5.63 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# Vodafone Germany's EBITDA
# Sample 1872: Q: What was the previous year's EBITDA? | GT: 5.08 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available".
#
# Chart:
# | Year | Revenue | E
# Sample 1873: Q: What percentage of Google's revenue was generated in the UK in 2015? | GT: 10 | Pred:  Do not make up data. Do not say "The chart does not show". The chart shows the revenue distribution of Google across different countries in 201
# Sample 1874: Q: Which country has the most markets? | GT: France | Pred:  Do not make up data. Do not say "Based on the chart...". Do not say "The country with the most markets is...". The country with
# Sample 1875: Q: What was the highest salary in the cruise industry in 2019? | GT: 9.93 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# Thought: The chart does not contain
# Sample 1876: Q: How much did the cruise industry pay in employee wages in 2009? | GT: 5.48 | Pred:  Do not make up data. If the data is not available in the chart, say "Data not available in chart".
#
# Available data: 2009
# Sample 1877: Q: How much was the expenses of the Green Bay Packers in 2017? | GT: 376.1 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available".
#
# Chart: None
# Answer: Data not available
# Sample 1878: Q: What percentage of all legal abortions in Alabama were performed on Hispanic women in 2018? | GT: 5.1 | Pred:  Avoid making up data or inferences. If the data is not available in the chart, respond with 'Data not available in chart'.
#
# % of all legal abortions
# Sample 1879: Q: What was the import trade value of bamboo and rattan furniture in the United States in 2015? | GT: 21.07 | Pred:  The chart is as follows: \begin{table}[h] \begin{tabular}{|c|c|c|c|c|c|
# Sample 1880: Q: What was the import trade value of bamboo and rattan furniture between 2015 and 2016? | GT: 18.7 | Pred:  The chart shows the import trade value of bamboo and rattan furniture between 2015 and 2016. In 2015
# Sample 1881: Q: How much did the import trade value of bamboo and rattan furniture increase between 2011 and 2016? | GT: 21.07 | Pred:  The chart shows the import trade value of bamboo and rattan furniture in China from 2011 to 2016. The values are in
# Sample 1882: Q: What was the revenue from video analytics in 2015? | GT: 858 | Pred:  Do not make up data. Do not say "Insufficient data". Do not say "I can't answer that". Do not say "Not enough information".
# Sample 1883: Q: What religion were about 116,000 Canadian citizens, permanent and non-permanent residents of Prince Edward Island identified as in 2011? | GT: Christian | Pred:  Do not make up data. Do not say "Based on the chart...". Do not say "According to the chart...". Do not say "The data
# Sample 1884: Q: When did the value of gross written premiums by life insurance companies on the domestic market in Malta increase? | GT: 2012 | Pred:  Do not make up data or statistics. If the information is not available in the chart, respond with "Insufficient data in chart to answer the question."
#
# ?
# Sample 1885: Q: What was the peak value of gross written premiums in Malta in 2018? | GT: 415 | Pred:  The chart shows the following data: In 2018, the peak value of gross written premiums in Malta was 100 million euros.
#
# 1
# Sample 1886: Q: What was the value of life insurance premiums in 2019? | GT: 378 | Pred:  Do not make up data. If the data is not available in the chart, say "Data not available in chart".
#
# ?
# ?
# ?
# ?
#
# Sample 1887: Q: How many UCI beds were there in Mexico City in April of 2020? | GT: 453 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# Number of UCI beds in Mexico
# Sample 1888: Q: How many adult intensive care units were in Mexico City in April 2020? | GT: 891 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# Number of adult intensive care units in
# Sample 1889: Q: Which social media site accounted for 57.52 percent of all social media site visits in Canada in May 2021? | GT: Facebook | Pred:  The chart shows the percentage of social media site visits in Canada in May 2021. Facebook accounted for 57.52 percent of all
# Sample 1890: Q: Who is the career touchdown leader of the Atlanta Falcons? | GT: Roddy White | Pred:  Each row in the chart represents a player. The columns are: Name, Position, Games, Touchdowns, Receptions, Yards, and Yards
# Sample 1891: Q: How many career touchdowns has Roddy White scored? | GT: 63 | Pred:  Each row in the chart represents a different player. The first column is the player's name. The second column is the player's position. The third column is
# Sample 1892: Q: What percentage of Rio 2016 viewers were women? | GT: 22 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# % of Rio 201
# Sample 1893: Q: What percentage of India's GDP did military expenditure amount to in 2019? | GT: 2.4 | Pred:  Do not make up data. Do not say "Insufficient data". Do not say "I cannot answer that". Do not say "The chart does not show
# Sample 1894: Q: What was Ethiopia's share in the global gross domestic product adjusted for Purchasing Power Parity in 2020? | GT: 0.22 | Pred:  The chart shows the following data: Ethiopia's share in the global gross domestic product adjusted for Purchasing Power Parity in 2020 was 0
# Sample 1895: Q: How much revenue did A.P. M ller - Maersk A/S generate from its ocean segment in 2020? | GT: 29.18 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# We are not given a chart.
# Sample 1896: Q: How much money did pirates receive in ransom for the release of the oil tanker Savina Caylyn? | GT: 11.5 | Pred:  Table cells in one row are seperated by '|', and different rows are seperated by '
# '.
#
# Table:
# | Date | Location | Event | Amount |
# |
# Sample 1897: Q: Which beer brand topped the beer production volume in Germany in 2016? | GT: Krombacher | Pred:  Each chart has a title, x-axis, y-axis, and data. The data is given as a list of lists, where each inner list represents a row
# Sample 1898: Q: How much did Manchester United's operating expenses in 2020 amount to? | GT: 645.88 | Pred:  Do not make up data or statistics. If the data is not available in the chart, respond with 'Data not available'.
#
# Thought: The chart does not contain
# Sample 1899: Q: What percentage of the Dominican Republic's GDP would be lost as a result of the COVID-19 pandemic? | GT: 0.8 | Pred:  The chart shows the following data:
#
# | Country | GDP Loss (%) |
# |---------|--------------|
# | Argentina | 12.5 |
# | Brazil |
# Sample 1900: Q: What percentage of the Dominican Republic's GDP would be affected by the COVID-19 pandemic? | GT: 6.1 | Pred:  Do not make up data. Do not say things like 'Based on the chart' or 'As shown in the chart'. Do not say things like 'The
# Sample 1901: Q: What percentage of Netflix subscribers said they would keep the service if the monthly price increased by five dollars per month? | GT: 53 | Pred:  Do not make up data. Do not say "Insufficient data". Do not say "I cannot answer that". Do not say "I don't know".
# Sample 1902: Q: Which candidate received the most donations from the oil and gas industry? | GT: Hillary Clinton | Pred:  Each row in the chart represents a candidate. Each column represents a different industry. The values in the cells represent the amount of money (in thousands of dollars)
# Sample 1903: Q: When is the forecasted year with the highest consumption volume? | GT: 2020 | Pred:  Do not make up data. Do not say "Based on the chart...". Just answer the question. Question: When is the forecasted year with the highest
# Sample 1904: Q: What is the average annual consumption of biodiesel in OECD countries? | GT: 21759.24 | Pred:  The chart shows the average annual consumption of biodiesel in OECD countries in million tonnes. The values are: France: 1.2, Germany: 1
# Sample 1905: Q: In what year did the turnover of the retail sale of leisure products increase to 6.7 billion British pounds? | GT: 2017 | Pred:  The chart shows the turnover of the retail sale of leisure products in the UK from 1990 to 2000.
#
# 1990
# Sample 1906: Q: What percentage of 17 year olds attended school? | GT: 93.3 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# 17 year olds: 9
# Sample 1907: Q: What percentage of 14 year olds were schooled in 2017-2018? | GT: 98.8 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# We are given a question about the
# Sample 1908: Q: What was Sweden's per capita gross domestic product in kronor in 2019? | GT: 488 | Pred:  The chart has the following columns: Country, Year, GDP (in USD), GDP per capita (in USD), GDP (in EUR), GDP per capita (
# Sample 1909: Q: What was the value of the gross domestic product in Sweden in kronor in 2019? | GT: 488 | Pred:  Do not make up data. If the chart does not contain the information, respond with "Data not available".\n\nChart content: None
# \n\n
# Sample 1910: Q: In what year did the per capita gross domestic product reach its highest value? | GT: 2019 | Pred:  Do not make up data or statistics. If the chart does not contain the necessary information, respond with "Cannot be determined". The chart shows the per capita gross
# Sample 1911: Q: What was the population of Eswatini in 2017? | GT: 1.1 | Pred:  Do not make up data. If the data is not available in the chart, respond with "Data not available in chart".
#
# Population of Eswatini (
# Sample 1912: Q: What was the inflation rate in Suriname in 2019? | GT: 4.39 | Pred:  The chart shows the inflation rate in Suriname from 2015 to 2020.
#
# In 2019, the inflation rate
# Sample 1913: Q: What was the share of consumers who wrote checks in 2018? | GT: 31 | Pred:  Do not make up data. Do not say "Insufficient data". Do not say "I cannot answer that". Do not say "The chart does not show
# Sample 1914: Q: How many specialised stores were there in the UK in March of 2020? | GT: 15 | Pred:  The chart shows the number of specialised stores in the UK from 2010 to 2020.
#
# In March 2020,
# Sample 1915: Q: Which country is the most active in CAR cell therapy trials? | GT: China | Pred:  Each row in the chart represents a country, and each column represents a type of therapy. The columns are: CAR T-cell therapy, CAR NK-cell therapy,
# Sample 1916: Q: What was the most valuable British-Dutch oil and gas company in 2021? | GT: Shell | Pred:  Do not make up data. Do not say "Based on the chart...". Just answer the question.
#
# The most valuable British-Dutch oil and gas company in
# Sample 1917: Q: What was the only brand in the top ten with headquarters outside of the UK? | GT: Shell | Pred:  The chart shows the top 10 brands by market capitalization in the UK as of 2023. The brands and their headquarters are:
# Sample 1918: Q: What was the second most valuable oil and gas company in the UK in 2021? | GT: BP | Pred:  Do not make up data. Do not say "Based on the chart...". The chart shows the market capitalization of the top 5 oil and gas companies
# Sample 1919: Q: Where did migrants arrive from January to December 2018? | GT: Pozzallo | Pred:  Do not make up data. Do not say "The chart shows". Do not say "Based on the chart". Do not say "According to the chart".
# Sample 1920: Q: Which country ranked second in the Italian migration chart? | GT: Lampedusa | Pred:  Do not make up information. Do not say "Based on the chart...". Just give the final answer.
#
# France
# Germany
# United Kingdom
# Spain
# Italy
#
# ==============================
# CLIP → Qwen PROJECTION RESULTS
# ==============================
# Total samples: 1920
# Exact Accuracy: 0.0000
# Relaxed Accuracy: 0.0354

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, CLIPProcessor, CLIPModel
device = "cuda" if torch.cuda.is_available() else "cpu"

# CLIP model
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
# Out:
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]
# CLIPModel LOAD REPORT from: openai/clip-vit-base-patch32
# Key                                  | Status     |  |
# -------------------------------------+------------+--+-
# vision_model.embeddings.position_ids | UNEXPECTED |  |
# text_model.embeddings.position_ids   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
# Qwen model
tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-4B-Instruct-2507")
qwen_model = AutoModelForCausalLM.from_pretrained("Qwen/Qwen3-4B-Instruct-2507").to(device)

# Qwen
qwen_model.eval().to(device)
for p in qwen_model.parameters():
    p.requires_grad = False  # freeze Qwen
# Out:
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]

# %%
import torch.nn as nn
clip_dim = 768      # CLIP-ViT-B/32 image embedding size
qwen_dim = 2560     # Qwen3B/4B input embedding size
projection = nn.Linear(clip_dim, qwen_dim).to(device)

# %%
from torch import nn, optim

optimizer = optim.Adam(projection.parameters(), lr=1e-4)
loss_fn = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)

# %%
def extract_clip_embedding(img):
    """Get CLIP embedding for a single PIL image"""
    inputs = clip_processor(images=img, return_tensors="pt").to(device)
    with torch.no_grad():
        # This returns a BaseModelOutputWithPooling sometimes
        output = clip_model.get_image_features(**inputs)

        # Convert to a tensor if it's not already
        if hasattr(output, "last_hidden_state"):  # old CLIP versions
            img_emb = output.last_hidden_state[:, 0, :]
        elif isinstance(output, (tuple, list)):
            img_emb = output[0]
        else:
            img_emb = output  # should already be a tensor

        # Make sure it's float32 on the right device
        img_emb = img_emb.float().to(device)

    return img_emb  # [1, clip_dim]



def generate_answer_from_clip(img_emb, question):
    """Project image embedding, prepend to question, and generate answer"""
    # Project image embedding
    projected_emb = projection(img_emb)  # [1, qwen_hidden_dim]

    # Build prompt with question
    prompt = f"Question: {question}\nAnswer:"
    messages = [{"role": "user", "content": prompt}]

    # Tokenize prompt
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_dict=True,
        return_tensors="pt"
    ).to(device)

    # Prepend projected image embedding to input embeddings
    qwen_inputs = qwen_model.get_input_embeddings()(inputs["input_ids"])
    projected_emb = projected_emb.to(qwen_inputs.dtype)
    combined_emb = torch.cat([projected_emb.unsqueeze(1), qwen_inputs], dim=1)

    # Generate
    with torch.no_grad():
        outputs = qwen_model.generate(
            inputs_embeds=combined_emb,
            max_new_tokens=60,
            do_sample=False
        )

    answer = tokenizer.decode(outputs[0][combined_emb.shape[1]:], skip_special_tokens=True)
    return answer.strip()

def normalize_text(text):
    return text.lower().strip()

def relaxed_numeric_match(pred, gt):
    try:
        pred_val = float(pred)
        gt_val = float(gt)
        return abs(pred_val - gt_val) / max(1.0, abs(gt_val)) <= 0.05
    except:
        return False

# %%
split_list = [dict(ex) for ex in ds["val"].select(range(50))]
results = []
exact_correct = 0
relaxed_correct = 0
total = 0

for ex in tqdm(split_list):
    img = ex["image"]
    question = ex["query"]
    gt_list = ex["label"]

    pred = generate_answer_from_clip(extract_clip_embedding(img), question)
    pred_norm = normalize_text(pred)

    exact = False
    relaxed = False
    for gt in gt_list:
        gt_norm = normalize_text(str(gt))
        if pred_norm == gt_norm:
            exact = True
            relaxed = True
            break
        if relaxed_numeric_match(pred_norm, gt_norm):
            relaxed = True

    if exact:
        exact_correct += 1
    if relaxed:
        relaxed_correct += 1
    total += 1

    results.append({
        "question": question,
        "ground_truth": gt_list,
        "prediction": pred,
        "exact_match": exact,
        "relaxed_match": relaxed
    })

# ------------------------------
# 5. Metrics
# ------------------------------
exact_acc = exact_correct / total
relaxed_acc = relaxed_correct / total
print("\n==============================")
print("SIMPLE CLIP-TO-QWEN BASELINE RESULTS")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_acc:.4f}")
print(f"Relaxed Accuracy (±5%): {relaxed_acc:.4f}")

df = pd.DataFrame(results)
df.to_csv("chartqa_clip_qwen_results_50.csv", index=False)
# Out:
#  12%|█▏        | 6/50 [00:05<00:39,  1.12it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3744837376.py in <cell line: 0>()
#      10     gt_list = ex["label"]
#      11
# ---> 12     pred = generate_answer_from_clip(extract_clip_embedding(img), question)
#      13     pred_norm = normalize_text(pred)
#      14
#
# /tmp/ipython-input-2773402715.py in generate_answer_from_clip(img_emb, question)
#      47     # Generate
#      48     with torch.no_grad():
# ---> 49         outputs = qwen_model.generate(
#      50             inputs_embeds=combined_emb,
#      51             max_new_tokens=60,
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     118     def decorate_context(*args, **kwargs):
#     119         with ctx_factory():
# --> 120             return func(*args, **kwargs)
#     121
#     122     return decorate_context
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, custom_generate, **kwargs)
#    2667
#    2668         # 9. Call generation mode
# -> 2669         result = decoding_method(
#    2670             self,
#    2671             input_ids,
#
# /usr/local/lib/python3.12/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    2872                 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2873                 with self._optimize_model_for_decode():
# -> 2874                     outputs = model_forward(**model_inputs, return_dict=True)
#    2875             prefill_consumed = True
#    2876             model_kwargs = self._update_model_kwargs_for_generation(
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     833         if return_dict_passed is not None:
#     834             return_dict = return_dict_passed
# --> 835         output = func(self, *args, **kwargs)
#     836         if not return_dict and not isinstance(output, tuple):
#     837             output = output.to_tuple()
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, cache_position, logits_to_keep, **kwargs)
#     503         "Hey, are you conscious? Can you talk to me?\nI'm not conscious, but I can talk to you."
#     504         ```"""
# --> 505         outputs: BaseModelOutputWithPast = self.model(
#     506             input_ids=input_ids,
#     507             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#    1000                         outputs = func(self, *args, **kwargs)
#    1001                 else:
# -> 1002                     outputs = func(self, *args, **kwargs)
#    1003             except TypeError as original_exception:
#    1004                 # If we get a TypeError, it's possible that the model is not receiving the recordable kwargs correctly.
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, cache_position, **kwargs)
#     433
#     434         for decoder_layer in self.layers[: self.config.num_hidden_layers]:
# --> 435             hidden_states = decoder_layer(
#     436                 hidden_states,
#     437                 attention_mask=causal_mask_mapping[decoder_layer.attention_type],
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#      91
#      92             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# ---> 93         return super().__call__(*args, **kwargs)
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, cache_position, position_embeddings, **kwargs)
#     321         hidden_states = self.input_layernorm(hidden_states)
#     322         # Self Attention
# --> 323         hidden_states, _ = self.self_attn(
#     324             hidden_states=hidden_states,
#     325             attention_mask=attention_mask,
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/qwen3/modeling_qwen3.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, cache_position, **kwargs)
#     263
#     264         query_states = self.q_norm(self.q_proj(hidden_states).view(hidden_shape)).transpose(1, 2)
# --> 265         key_states = self.k_norm(self.k_proj(hidden_states).view(hidden_shape)).transpose(1, 2)
#     266         value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     267
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# KeyboardInterrupt:

# %%
import torch.nn as nn
clip_dim = 512      # CLIP-ViT-B/32 image embedding size
qwen_dim = 2560     # Qwen3B/4B input embedding size
proj_tokens = 4  # number of "virtual tokens" projected from CLIP
projection = nn.Sequential(
    nn.Linear(clip_dim, 1024),
    nn.ReLU(),
    nn.Linear(1024, qwen_dim)
).to(device)

from torch import nn, optim

optimizer = optim.Adam(projection.parameters(), lr=1e-4)
loss_fn = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)

def extract_clip_embedding(img):
    """Get CLIP embedding for a single PIL image"""
    inputs = clip_processor(images=img, return_tensors="pt").to(device)
    with torch.no_grad():
        output = clip_model.get_image_features(**inputs)
        # Handle BaseModelOutputWithPooling
        if hasattr(output, "pooler_output"):
            img_emb = output.pooler_output
        elif hasattr(output, "last_hidden_state"):
            img_emb = output.last_hidden_state[:, 0, :]
        elif isinstance(output, (tuple, list)):
            img_emb = output[0]
        else:
            img_emb = output  # already tensor

        img_emb = img_emb.float().to(device)

    return img_emb  # [1, clip_dim]



def prepare_inputs_for_training(img_emb, question):
    projected_emb = projection(img_emb)  # [1, qwen_dim]

    prompt = f"Question: {question}\nAnswer:"
    messages = [{"role": "user", "content": prompt}]
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_dict=True,
        return_tensors="pt"
    ).to(device)

    qwen_inputs = qwen_model.get_input_embeddings()(inputs["input_ids"])
    projected_emb = projected_emb.to(qwen_inputs.dtype)
    combined_emb = torch.cat([projected_emb.unsqueeze(1), qwen_inputs], dim=1)

    # Prepend padding token for labels to match new seq_len
    pad_label = torch.full((inputs["input_ids"].shape[0], 1),
                           -100,
                           #tokenizer.pad_token_id,
                           device=inputs["input_ids"].device,
                           dtype=inputs["input_ids"].dtype)
    labels = torch.cat([pad_label, inputs["input_ids"]], dim=1)

    return combined_emb, labels



def generate_answer_from_clip(img_emb, question, max_new_tokens=60):
    """Inference: generate answer from image + question"""
    projected_emb = projection(img_emb)
    prompt = f"Question: {question}\nAnswer:"
    messages = [{"role": "user", "content": prompt}]
    inputs = tokenizer.apply_chat_template(
        messages,
        add_generation_prompt=True,
        tokenize=True,
        padding=True,
        return_dict=True,
        return_tensors="pt"
    ).to(device)

    qwen_inputs = qwen_model.get_input_embeddings()(inputs["input_ids"])
    projected_emb = projected_emb.to(qwen_inputs.dtype)
    combined_emb = torch.cat([projected_emb.unsqueeze(1), qwen_inputs], dim=1)

    with torch.no_grad():
        outputs = qwen_model.generate(
            inputs_embeds=combined_emb,
            max_new_tokens=max_new_tokens,
            num_beams=3,      # beam search
            do_sample=True,
        )

    answer = tokenizer.decode(outputs[0][combined_emb.shape[1]:], skip_special_tokens=True)
    return answer.strip()



def relaxed_numeric_match(pred, gt):
    try:
        pred_val = float(pred)
        gt_val = float(gt)
        return abs(pred_val - gt_val) / max(1.0, abs(gt_val)) <= 0.05
    except:
        return False

# %%
split_list = [dict(ex) for ex in ds["val"].select(range(50))]
epochs = 5
batch_size = 4

for epoch in range(epochs):
    total_loss = 0.0
    for i in tqdm(range(0, len(split_list), batch_size)):
        batch = split_list[i:i+batch_size]
        optimizer.zero_grad()
        batch_loss = 0.0

        for ex in batch:
            img = ex["image"]
            question = ex["query"]
            combined_emb, input_ids = prepare_inputs_for_training(extract_clip_embedding(img), question)

            outputs = qwen_model(inputs_embeds=combined_emb, labels=input_ids)
            loss = outputs.loss
            batch_loss += loss

        batch_loss = batch_loss / len(batch)
        batch_loss.backward()
        optimizer.step()
        total_loss += batch_loss.item()

    print(f"Epoch {epoch+1}/{epochs}, Loss: {total_loss/len(split_list):.4f}")


# ------------------------------
# 4️⃣ Evaluation
# ------------------------------
results = []
exact_correct = 0
relaxed_correct = 0
total = 0

for ex in tqdm(split_list):
    img = ex["image"]
    question = ex["query"]
    gt_list = ex["label"]

    pred = generate_answer_from_clip(extract_clip_embedding(img), question)
    pred_norm = pred.lower().strip()

    exact = False
    relaxed = False
    for gt in gt_list:
        gt_norm = str(gt).lower().strip()
        if pred_norm == gt_norm:
            exact = True
            relaxed = True
            break
        if relaxed_numeric_match(pred_norm, gt_norm):
            relaxed = True

    if exact: exact_correct += 1
    if relaxed: relaxed_correct += 1
    total += 1

    results.append({
        "question": question,
        "ground_truth": gt_list,
        "prediction": pred,
        "exact_match": exact,
        "relaxed_match": relaxed
    })

exact_acc = exact_correct / total
relaxed_acc = relaxed_correct / total

print("\n==============================")
print("TRAINED CLIP-TO-QWEN RESULTS")
print("==============================")
print(f"Total samples: {total}")
print(f"Exact Accuracy: {exact_acc:.4f}")
print(f"Relaxed Accuracy (±5%): {relaxed_acc:.4f}")

df = pd.DataFrame(results)
df.to_csv("chartqa_clip_qwen_trained_results_50.csv", index=False)
# Out:
# 100%|██████████| 13/13 [00:02<00:00,  5.29it/s]
# Epoch 1/5, Loss: 1.2546
# 100%|██████████| 13/13 [00:02<00:00,  5.27it/s]
# Epoch 2/5, Loss: 1.1980
# 100%|██████████| 13/13 [00:02<00:00,  5.27it/s]
# Epoch 3/5, Loss: 1.1238
# 100%|██████████| 13/13 [00:02<00:00,  5.30it/s]
# Epoch 4/5, Loss: 1.0532
# 100%|██████████| 13/13 [00:02<00:00,  5.31it/s]
# Epoch 5/5, Loss: 0.9752
# 100%|██████████| 50/50 [00:45<00:00,  1.09it/s]
# ==============================
# TRAINED CLIP-TO-QWEN RESULTS
# ==============================
# Total samples: 50
# Exact Accuracy: 0.0000
# Relaxed Accuracy (±5%): 0.0000
